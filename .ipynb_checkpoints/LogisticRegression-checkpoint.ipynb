# %%
# import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn import metrics, preprocessing
import seaborn as sns
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load dataset

# %%
#read data
data = pd.read_excel('default of credit card clients.xls')
data.head()
data.shape
# Out:
# (30001, 25)

# %% [markdown]
# **Information**
#
# This research employed a binary variable, default payment (Yes = 1, No = 0), as the response variable. This study reviewed the literature and used the following 23 variables as explanatory variables:<br>
# X1: Amount of the given credit (NT dollar): it includes both the individual consumer credit and his/her family (supplementary) credit.<br>
# X2: Gender (1 = male; 2 = female).<br>
# X3: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).<br>
# X4: Marital status (1 = married; 2 = single; 3 = others).<br>
# X5: Age (year).<br>
# X6 - X11: History of past payment. We tracked the past monthly payment records (from April to September, 2005) as follows: X6 = the repayment status in September, 2005; X7 = the repayment status in August, 2005; . . .;X11 = the repayment status in April, 2005. The measurement scale for the repayment status is: -1 = pay duly; 1 = payment delay for one month; 2 = payment delay for two months; . . .; 8 = payment delay for eight months; 9 = payment delay for nine months and above.<br>
# X12-X17: Amount of bill statement (NT dollar). X12 = amount of bill statement in September, 2005; X13 = amount of bill statement in August, 2005; . . .; X17 = amount of bill statement in April, 2005. <br>
# X18-X23: Amount of previous payment (NT dollar). X18 = amount paid in September, 2005; X19 = amount paid in August, 2005; . . .;X23 = amount paid in April, 2005.

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Convert Datatype from Object to Int

# %%
data=data.drop([0])

# %%
df = data.astype(int)
df.dtypes
# Out:
# Unnamed: 0    int64
# X1            int64
# X2            int64
# X3            int64
# X4            int64
# X5            int64
# X6            int64
# X7            int64
# X8            int64
# X9            int64
# X10           int64
# X11           int64
# X12           int64
# X13           int64
# X14           int64
# X15           int64
# X16           int64
# X17           int64
# X18           int64
# X19           int64
# X20           int64
# X21           int64
# X22           int64
# X23           int64
# Y             int64
# dtype: object

# %%
df = df.drop(columns='Unnamed: 0')

# %% [markdown]
# ### Delete Outliers

# %%
# df = df.drop(df[(df['X6']==0) | (df['X6']==-2)].index) 
# df = df.drop(df[(df['X7']==0) | (df['X7']==-2)].index)

# %%
df["X6"][df.X6<1]=-1
df["X7"][df.X7<1]=-1
df["X8"][df.X8<1]=-1
df["X9"][df.X9<1]=-1
df["X10"][df.X10<1]=-1
df["X11"][df.X11<1]=-1

# %%
df.shape
# Out:
# (30000, 24)

# %% [markdown]
# ## Explore Dataset

# %% [markdown]
# ### Correlation Coefficients to default

# %%
df.corr()['Y'] #Show the correlation Coefficients to default
# Out:
# X1    -0.153520
# X2    -0.039961
# X3     0.028006
# X4    -0.024339
# X5     0.013890
# X6     0.398636
# X7     0.333438
# X8     0.292026
# X9     0.274779
# X10    0.266465
# X11    0.248252
# X12   -0.019644
# X13   -0.014193
# X14   -0.014076
# X15   -0.010156
# X16   -0.006760
# X17   -0.005372
# X18   -0.072929
# X19   -0.058579
# X20   -0.056250
# X21   -0.056827
# X22   -0.055124
# X23   -0.053183
# Y      1.000000
# Name: Y, dtype: float64

# %%
corr_matrix = df.corr().abs()
mask = np.array(corr_matrix)
mask[np.tril_indices_from(mask)] = False
fig,ax= plt.subplots()
fig.set_size_inches(30,30)
sns.heatmap(corr_matrix,mask=mask,vmax=.5,  square=True,annot=True)
# Out:
# <AxesSubplot:>

# %%
# Show default with grades
f,ax=plt.subplots(1,2,figsize=(18,8))
df[['X6','Y']].groupby(['X6']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Default ratio vs Repayment status')
sns.countplot(x= 'X6',hue='Y',data= df,ax=ax[1])
ax[1].set_title('Repayment status: Default vs non-default')
plt.show()

# %%
# Show the default ratio of different grades
grade_order=[-1,1,2,3,4,5,6,7,8]
sns.barplot(x='X6',y='Y',data=df,order=grade_order)
plt.show()

# %% [markdown]
# ## Train with selected features (Not used, coz performs worse)

# %%
#importing all the required ML packages
import sklearn
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn import metrics #accuracy measure
from sklearn.linear_model import LinearRegression #LinearRegression
from sklearn.linear_model import LogisticRegression #LogisticRegression

# %%
# Put all selected features in a new dataset: data_model.
data_model= df[['X1', 'X6', 'X7', 'X8', 'X9','X10','X11','Y']]
data_model.head()
# Out:
#        X1  X6  X7  X8  X9  X10  X11  Y
# 1   20000   2   2  -1  -1   -1   -1  1
# 2  120000  -1   2  -1  -1   -1    2  1
# 3   90000  -1  -1  -1  -1   -1   -1  0
# 4   50000  -1  -1  -1  -1   -1   -1  0
# 5   50000  -1  -1  -1  -1   -1   -1  0

# %%
# Show basic information about data_model.
data_model.describe()
# Out:
#                    X1            X6            X7            X8            X9  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667     -0.415967     -0.532033     -0.555500     -0.624233
# std     129747.661567      1.142591      1.146393      1.126275      1.067522
# min      10000.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 25%      50000.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%     140000.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 75%     240000.000000     -1.000000     -1.000000     -1.000000     -1.000000
# max    1000000.000000      8.000000      8.000000      8.000000      8.000000
#
#                 X10           X11             Y
# count  30000.000000  30000.000000  30000.000000
# mean      -0.679567     -0.670800      0.221200
# std        1.001726      1.005283      0.415062
# min       -1.000000     -1.000000      0.000000
# 25%       -1.000000     -1.000000      0.000000
# 50%       -1.000000     -1.000000      0.000000
# 75%       -1.000000     -1.000000      0.000000
# max        8.000000      8.000000      1.000000

# %%
# Divide the whole data to 2 parts, 80% as training set, 20% as test set
train,test=train_test_split(data_model,test_size=0.2,random_state=0,stratify=df['Y'])

train_X=train[train.columns[:-1]]
train_y=train[train.columns[-1]]

test_X=test[test.columns[:-1]]
test_y=test[test.columns[-1]]

# %%
clf = LogisticRegression(random_state=0).fit(train_X, train_y)
print("The prediction values are: ",clf.predict(test_X))
# Out:
# The prediction values are:  [0 0 0 ... 1 0 0]

# %%
# Probability of defualt and non-defaultproba=clf.predict_proba(test_X) 
default_proba = []
for line in clf.predict_proba(test_X):
    default_proba.append(line[1])
    
print("The prediction default probabilities are: ",default_proba[0:5],'...')
# Out:
# The prediction default probabilities are:  [0.17417113845330062, 0.24582362213524103, 0.06027408862085164, 0.17417113845330062, 0.4274675090157668] ...

# %%
prediction3=clf.predict(test_X)
print("The prediction values are: ",prediction3)
print('The f1_score of the Logistuc Regression is',f1_score(prediction3,test_y,average='weighted'))
# Out:
# The prediction values are:  [0 0 0 ... 1 0 0]
# The f1_score of the Logistuc Regression is 0.8306209024952308

# %% [markdown]
# ## Logistic Regression（default）

# %%
# Divide the whole data to 2 parts, 80% as training set, 20% as test set
train,test=train_test_split(df,test_size=0.2,random_state=0,stratify=df['Y'])

train_X=train[train.columns[:-1]]
train_y=train[train.columns[-1]]

test_X=test[test.columns[:-1]]
test_y=test[test.columns[-1]]

# %%
#train_X.head()

# %%
train_y.head()
# Out:
# 6671     0
# 12887    1
# 16219    0
# 5773     0
# 22647    1
# Name: Y, dtype: int64

# %%
clf = LogisticRegression(random_state=0).fit(train_X, train_y)
print("The prediction values are: ",clf.predict(test_X))
# Out:
# The prediction values are:  [0 0 0 ... 0 0 0]

# %%
# Probability of defualt and non-defaultproba=clf.predict_proba(test_X) 
default_proba = []
for line in clf.predict_proba(test_X):
    default_proba.append(line[1])
    
print("The prediction default probabilities are: ",default_proba[0:5],'...')
# Out:
# The prediction default probabilities are:  [0.30323518474228967, 0.15648569993889921, 0.007155009434807764, 0.3457493131827314, 0.35891621967280996] ...

# %%
prediction3=clf.predict(test_X)
print("The prediction values are: ",prediction3)
print('The f1_score of the Logistuc Regression is',f1_score(prediction3,test_y,average='weighted'))
# Out:
# The prediction values are:  [0 0 0 ... 0 0 0]
# The f1_score of the Logistuc Regression is 0.875416291854073

# %%
flatten_data = prediction3.flatten()
list_data = flatten_data.tolist()
set_data = set(list_data)
set_data
# Out:
# {0, 1}

# %% [markdown]
# ## Hyperparameter tuning

# %% [markdown]
# ### penalty{‘l1’, ‘l2’, ‘elasticnet’},
#
# **L1 Regularization**, also called a **lasso regression**, adds the **“absolute value of magnitude”** of the coefficient as a penalty term to the loss function.
#
# **L2 Regularization**, also called a **ridge regression**, adds the **“squared magnitude”** of the coefficient as the penalty term to the loss function.

# %% [markdown]
# The 'liblinear' solver does not work without regularization.<br>
# 'newton-cg', 'sag', 'saga' and 'lbfgs' do not support L1 regularization.<br>
# 'saga' is the only solver that supports elastic net regularization.

# %% [markdown]
# #### L1

# %%
clf = sklearn.linear_model.LogisticRegression(penalty='l1',random_state=0, solver='liblinear')
clf.fit(train_X, train_y)
prediction=clf.predict(test_X)
print("The prediction values are: ",prediction)
print('The f1_score of the Logistuc Regression is',f1_score(prediction,test_y,average='weighted'))
# Out:
# The prediction values are:  [0 0 0 ... 0 0 0]
# The f1_score of the Logistuc Regression is 0.8447492823129948

# %% [markdown]
# #### L2

# %%
clf = sklearn.linear_model.LogisticRegression(penalty='l2',random_state=0, solver='liblinear')
clf.fit(train_X, train_y)
prediction=clf.predict(test_X)
print("The prediction values are: ",prediction)
print('The f1_score of the Logistuc Regression is',f1_score(prediction,test_y,average='weighted'))
# Out:
# The prediction values are:  [0 0 0 ... 0 0 0]
# The f1_score of the Logistuc Regression is 0.875416291854073

# %%
clf = sklearn.linear_model.LogisticRegression(penalty='l2',random_state=0, solver='saga')
clf.fit(train_X, train_y)
prediction=clf.predict(test_X)
print("The prediction values are: ",prediction)
print('The f1_score of the Logistuc Regression is',f1_score(prediction,test_y,average='weighted'))
# Out:
# The prediction values are:  [0 0 0 ... 0 0 0]
# The f1_score of the Logistuc Regression is 0.8756675723789

# %% [markdown]
# #### elasticnet

# %%
print("\nLogistic Regression Model............................................\n")
f1=[]
for r in np.arange(0, 1, 0.01):
    clf = sklearn.linear_model.LogisticRegression(penalty='elasticnet',l1_ratio=r,random_state=0, solver='saga')
    clf.fit(train_X, train_y)
    prediction=clf.predict(test_X)
    f1.append(f1_score(prediction,test_y,average='weighted'))
# Write code to plot your results here
#plt.figure(figsize=(8, 5), constrained_layout=True)
print("\n............................................\n")
print("The highest f1 score is ", max(f1), "occurs at", f1.index(max(f1)))
# Out:
# Logistic Regression Model............................................
#
#
# ............................................
#
# The highest f1 score is  0.8756675723789 occurs at 0

# %%
# fig2=plt.figure(figsize=(10, 5))
# x = np.arange(0, 1, 0.01)
# plt.plot(x,f1, label = 'F1-score')

# #plt.xscale('symlog')
# plt.xlabel('L1 ratio')
# plt.ylabel('F1-score')
# plt.ylim(0.86,0.88)
# plt.grid()
# plt.legend()

# %%
# clf = sklearn.linear_model.LogisticRegression(penalty='elasticnet',l1_ratio=0.1,random_state=0, solver='saga')
# clf.fit(train_X, train_y)
# prediction=clf.predict(test_X)
# print("The prediction values are: ",prediction)
# print('The f1_score of the Logistuc Regression is',f1_score(prediction,test_y,average='weighted'))

# %% [markdown]
# **Result**: L2 works best

# %% [markdown]
# ### C (panelty=l2)
#
# Inverse of regularization strength; must be a positive float. Like in support vector machines, smaller values specify stronger regularization.

# %%
print("\nLogistic Regression Model............................................\n")
C=np.arange(0.01, 1,0.01)
CValue=[]
f1=[]
for c in C:
    clf = sklearn.linear_model.LogisticRegression(penalty='l2',C=c,random_state=0, solver='liblinear')
    CValue.append(c)
    clf.fit(train_X, train_y)
    prediction=clf.predict(test_X)
    f1.append(f1_score(prediction,test_y,average='weighted'))
# Write code to plot your results here
#plt.figure(figsize=(8, 5), constrained_layout=True)
print("\n............................................\n")
print("The highest f1 score is ", max(f1), "occurs at", f1.index(max(f1)),", when c =",CValue[f1.index(max(f1))])
# Out:
# Logistic Regression Model............................................
#
#
# ............................................
#
# The highest f1 score is  0.875416291854073 occurs at 1 , when c = 0.02

# %%
fig2=plt.figure(figsize=(10, 5))
x = C
plt.plot(x,f1, label = 'F1-score')

#plt.xscale('symlog')
plt.xlabel('Inverse of regularization strength')
plt.ylabel('F1-score')

plt.grid()
plt.legend()

# %% [markdown]
# **Best setting**: L2 with C=0.02

# %% [markdown]
# ## Comments
# It seems that the performance of Logistic regression can no longer be improved, with the F1 socre reaches up to 0.875

# %% [markdown]
# ## Train with Standardization data

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Divide the whole data to 2 parts, 80% as training set, 20% as test set
train,test=train_test_split(df,test_size=0.2,random_state=0,stratify=df['Y'])

train_X=train[train.columns[:-1]]
train_y=train[train.columns[-1]]

test_X=test[test.columns[:-1]]
test_y=test[test.columns[-1]]

# %%
scaler = StandardScaler()
train_X = pd.DataFrame(scaler.fit_transform(train_X), columns=train_X.columns)
test_X = pd.DataFrame(scaler.fit_transform(test_X), columns=test_X.columns)

# %%
train_X
# Out:
#              X1        X2        X3        X4        X5        X6        X7  \
# 0      1.181870 -1.240623 -1.079839  0.858477 -1.029674 -0.512063 -0.409703
# 1      0.252354 -1.240623 -1.079839 -1.060800  0.494083 -0.512063 -0.409703
# 2     -0.367323  0.806047 -1.079839  0.858477  1.038281 -0.512063 -0.409703
# 3     -1.141920  0.806047 -1.079839  0.858477 -1.465033 -0.512063 -0.409703
# 4     -1.064461  0.806047  1.450909 -1.060800  0.711762 -0.512063 -0.409703
# ...         ...       ...       ...       ...       ...       ...       ...
# 23995 -0.677162  0.806047  0.185535 -1.060800  0.167563 -0.512063 -0.409703
# 23996 -0.057485  0.806047  0.185535 -1.060800 -0.267796 -0.512063 -0.409703
# 23997 -0.599703  0.806047  0.185535 -1.060800  1.255961 -0.512063 -0.409703
# 23998 -0.909541  0.806047  0.185535  0.858477 -0.703155  1.236090  2.197332
# 23999 -1.219380 -1.240623  0.185535  0.858477 -1.465033  1.236090  2.197332
#
#              X8        X9       X10  ...       X14       X15       X16  \
# 0     -0.395840 -0.353658 -0.323191  ... -0.478122 -0.486032 -0.666427
# 1     -0.395840 -0.353658 -0.323191  ... -0.586932 -0.634081 -0.569042
# 2     -0.395840 -0.353658 -0.323191  ...  0.587722  0.722846  0.909079
# 3     -0.395840 -0.353658 -0.323191  ... -0.665491 -0.670154 -0.666427
# 4     -0.395840 -0.353658 -0.323191  ... -0.485926 -0.634517 -0.169698
# ...         ...       ...       ...  ...       ...       ...       ...
# 23995 -0.395840 -0.353658 -0.323191  ... -0.042160  0.033160  0.137064
# 23996 -0.395840 -0.353658 -0.323191  ... -0.539935  0.143967 -0.545389
# 23997 -0.395840 -0.353658 -0.323191  ... -0.263151 -0.227129 -0.184834
# 23998  2.258332  2.451911 -0.323191  ...  0.028263  0.073175  0.142973
# 23999  2.258332  2.451911 -0.323191  ... -0.550619 -0.542183 -0.522924
#
#             X17       X18       X19       X20       X21       X22        X23
# 0     -0.656171 -0.264078 -0.181775 -0.296122 -0.311500 -0.312013  12.249169
# 1     -0.030126 -0.041420  0.050646 -0.153340  0.077286  0.839939  -0.017405
# 2      0.987761 -0.156202 -0.117812 -0.115437  0.155043 -0.077757  -0.075234
# 3     -0.651072 -0.339508 -0.215673 -0.292458 -0.311500 -0.292362   0.140115
# 4     -0.164117 -0.257886 -0.202881 -0.250651  1.632431 -0.243949  -0.218382
# ...         ...       ...       ...       ...       ...       ...        ...
# 23995  0.186146 -0.041836 -0.125780 -0.190582 -0.052310 -0.181871  -0.183593
# 23996 -0.618862 -0.193470  0.170560  2.847194 -0.211323 -0.168206  -0.297655
# 23997 -0.158968 -0.220439 -0.168853 -0.190582 -0.181905 -0.181871  -0.183593
# 23998  0.154696 -0.339508 -0.061171 -0.310719 -0.198040 -0.199050  -0.128216
# 23999 -0.506412 -0.339508 -0.151624 -0.310719 -0.300226 -0.300495  -0.287332
#
# [24000 rows x 23 columns]

# %%
train_y
# Out:
# 6671     0
# 12887    1
# 16219    0
# 5773     0
# 22647    1
#         ..
# 25589    0
# 258      0
# 8604     0
# 12913    1
# 20374    1
# Name: Y, Length: 24000, dtype: int64

# %%
clf = sklearn.linear_model.LogisticRegression(penalty='l2',C=0.02,random_state=0, solver='liblinear')
clf.fit(train_X, train_y)
prediction=clf.predict(test_X)
print(f1_score(prediction,test_y,average='weighted'))
# Out:
# 0.8441712541938705

# %% [markdown]
# **Not good**
