# %% [markdown]
# # Algorithm Selection

# %%
# import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn import metrics, preprocessing
import seaborn as sns
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load dataset

# %%
#read data
data = pd.read_excel('default of credit card clients.xls')
data.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
#         X21       X22       X23                           Y
# 0  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1         0         0         0                           1
# 2      1000         0      2000                           1
# 3      1000      1000      5000                           0
# 4      1100      1069      1000                           0
#
# [5 rows x 25 columns]

# %% [markdown]
# **Information**
#
# This research employed a binary variable, default payment (Yes = 1, No = 0), as the response variable. This study reviewed the literature and used the following 23 variables as explanatory variables:<br>
# X1: Amount of the given credit (NT dollar): it includes both the individual consumer credit and his/her family (supplementary) credit.<br>
# X2: Gender (1 = male; 2 = female).<br>
# X3: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).<br>
# X4: Marital status (1 = married; 2 = single; 3 = others).<br>
# X5: Age (year).<br>
# X6 - X11: History of past payment. We tracked the past monthly payment records (from April to September, 2005) as follows: X6 = the repayment status in September, 2005; X7 = the repayment status in August, 2005; . . .;X11 = the repayment status in April, 2005. The measurement scale for the repayment status is: -1 = pay duly; 1 = payment delay for one month; 2 = payment delay for two months; . . .; 8 = payment delay for eight months; 9 = payment delay for nine months and above.<br>
# X12-X17: Amount of bill statement (NT dollar). X12 = amount of bill statement in September, 2005; X13 = amount of bill statement in August, 2005; . . .; X17 = amount of bill statement in April, 2005. <br>
# X18-X23: Amount of previous payment (NT dollar). X18 = amount paid in September, 2005; X19 = amount paid in August, 2005; . . .;X23 = amount paid in April, 2005.

# %% [markdown]
# ## Preprocess

# %% [markdown]
# ### Check missing values

# %%
data.isnull().sum() # check missing values
# Out:
# Unnamed: 0    0
# X1            0
# X2            0
# X3            0
# X4            0
# X5            0
# X6            0
# X7            0
# X8            0
# X9            0
# X10           0
# X11           0
# X12           0
# X13           0
# X14           0
# X15           0
# X16           0
# X17           0
# X18           0
# X19           0
# X20           0
# X21           0
# X22           0
# X23           0
# Y             0
# dtype: int64

# %%
data.dtypes
# Out:
# Unnamed: 0    object
# X1            object
# X2            object
# X3            object
# X4            object
# X5            object
# X6            object
# X7            object
# X8            object
# X9            object
# X10           object
# X11           object
# X12           object
# X13           object
# X14           object
# X15           object
# X16           object
# X17           object
# X18           object
# X19           object
# X20           object
# X21           object
# X22           object
# X23           object
# Y             object
# dtype: object

# %% [markdown]
# ### Convert Datatype from Object to Int

# %%
data=data.drop([0])

# %%
df = data.astype(int)
df.dtypes
# Out:
# Unnamed: 0    int64
# X1            int64
# X2            int64
# X3            int64
# X4            int64
# X5            int64
# X6            int64
# X7            int64
# X8            int64
# X9            int64
# X10           int64
# X11           int64
# X12           int64
# X13           int64
# X14           int64
# X15           int64
# X16           int64
# X17           int64
# X18           int64
# X19           int64
# X20           int64
# X21           int64
# X22           int64
# X23           int64
# Y             int64
# dtype: object

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df
# Out:
#            X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...    X15    X16    X17  \
# 1       20000   2   2   1  24   2   2  -1  -1   -2  ...      0      0      0
# 2      120000   2   2   2  26  -1   2   0   0    0  ...   3272   3455   3261
# 3       90000   2   2   2  34   0   0   0   0    0  ...  14331  14948  15549
# 4       50000   2   2   1  37   0   0   0   0    0  ...  28314  28959  29547
# 5       50000   1   2   1  57  -1   0  -1   0    0  ...  20940  19146  19131
# ...       ...  ..  ..  ..  ..  ..  ..  ..  ..  ...  ...    ...    ...    ...
# 29996  220000   1   3   1  39   0   0   0   0    0  ...  88004  31237  15980
# 29997  150000   1   3   2  43  -1  -1  -1  -1    0  ...   8979   5190      0
# 29998   30000   1   2   2  37   4   3   2  -1    0  ...  20878  20582  19357
# 29999   80000   1   3   1  41   1  -1   0   0    0  ...  52774  11855  48944
# 30000   50000   1   2   1  46   0   0   0   0    0  ...  36535  32428  15313
#
#          X18    X19    X20   X21    X22   X23  Y
# 1          0    689      0     0      0     0  1
# 2          0   1000   1000  1000      0  2000  1
# 3       1518   1500   1000  1000   1000  5000  0
# 4       2000   2019   1200  1100   1069  1000  0
# 5       2000  36681  10000  9000    689   679  0
# ...      ...    ...    ...   ...    ...   ... ..
# 29996   8500  20000   5003  3047   5000  1000  0
# 29997   1837   3526   8998   129      0     0  0
# 29998      0      0  22000  4200   2000  3100  1
# 29999  85900   3409   1178  1926  52964  1804  1
# 30000   2078   1800   1430  1000   1000  1000  1
#
# [30000 rows x 24 columns]

# %% [markdown]
# ## Explore Dataset

# %%
df.shape
# Out:
# (30000, 24)

# %% [markdown]
# ### How many defaults ?

# %%
print('Not default', round(df['Y'].value_counts()[0]/len(df) * 100,2), '% of the dataset')
print('Default', round(df['Y'].value_counts()[1]/len(df) * 100,2), '% of the dataset')
# Out:
# Not default 77.88 % of the dataset
# Default 22.12 % of the dataset

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Y'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('default')
ax[0].set_ylabel('')
sns.countplot(data=df, x="Y", ax=ax[1])
ax[1].set_title('default')
plt.show()

# %% [markdown]
# ### Correlation Coefficients to default

# %%
df.corr()['Y'] #Show the correlation Coefficients to default
# Out:
# X1    -0.153520
# X2    -0.039961
# X3     0.028006
# X4    -0.024339
# X5     0.013890
# X6     0.324794
# X7     0.263551
# X8     0.235253
# X9     0.216614
# X10    0.204149
# X11    0.186866
# X12   -0.019644
# X13   -0.014193
# X14   -0.014076
# X15   -0.010156
# X16   -0.006760
# X17   -0.005372
# X18   -0.072929
# X19   -0.058579
# X20   -0.056250
# X21   -0.056827
# X22   -0.055124
# X23   -0.053183
# Y      1.000000
# Name: Y, dtype: float64

# %%
corr_matrix = df.corr().abs()
mask = np.array(corr_matrix)
mask[np.tril_indices_from(mask)] = False
fig,ax= plt.subplots()
fig.set_size_inches(30,30)
sns.heatmap(corr_matrix,mask=mask,vmax=.5,  square=True,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Observation
# X6 - X11 are highly correlated with Default <br>
# X6 - X11: History of past payment. We tracked the past monthly payment records (from April to September, 2005) as follows: X6 = the repayment status in September, 2005; X7 = the repayment status in August, 2005; . . .;X11 = the repayment status in April, 2005. The measurement scale for the repayment status is: -1 = pay duly; 1 = payment delay for one month; 2 = payment delay for two months; . . .; 8 = payment delay for eight months; 9 = payment delay for nine months and above.<br>

# %% [markdown]
# ## Generate training and test data

# %%
#importing all the required ML packages
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn import metrics #accuracy measure
from sklearn.linear_model import LinearRegression #LinearRegression
from sklearn.linear_model import LogisticRegression #LogisticRegression

# %%
# Divide the whole data to 2 parts, 80% as training set, 20% as test set
train,test=train_test_split(df,test_size=0.2,random_state=0,stratify=df['Y'])

train_X=train[train.columns[:-1]]
train_y=train[train.columns[-1]]

test_X=test[test.columns[:-1]]
test_y=test[test.columns[-1]]

# %%
train_X.head()
# Out:
#            X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...    X14    X15    X16  \
# 6671   320000   1   1   2  26  -1   0   0   0    0  ...  13917  12125      0
# 12887  200000   1   1   1  40  -1  -1  -1  -1   -1  ...   6360   2620   5900
# 16219  120000   2   1   2  45   0   0   0   0    0  ...  87941  89737  95451
# 5773    20000   2   1   2  22  -2  -2  -2  -2   -2  ...    904    304      0
# 22647   30000   2   3   1  42   0   0   0   0    0  ...  13375   2592  30094
#
#          X17   X18   X19   X20    X21    X22     X23
# 6671       0  1267  1700   243      0      0  220000
# 12887  37084  5007  7096  2620   6000  17703    4914
# 16219  97379  3079  3185  3251   7200   3600    3900
# 5773     302     0   913   304      0    302    7676
# 22647  29147  1371  1210  1000  30000   1046    1390
#
# [5 rows x 23 columns]

# %%
train_y.head()
# Out:
# 6671     0
# 12887    1
# 16219    0
# 5773     0
# 22647    1
# Name: Y, dtype: int64

# %% [markdown]
# ## Algorithm Comparison

# %% [markdown]
# ###  Decision Tree

# %%
model=DecisionTreeClassifier()
model.fit(train_X,train_y)
prediction1=model.predict(test_X)
print("The prediction values are: ",prediction1)
# Out:
# The prediction values are:  [0 0 0 ... 0 0 0]

# %%
print('The accuracy of the Decision Tree is',metrics.accuracy_score(prediction1,test_y))
# Out:
# The accuracy of the Decision Tree is 0.7236666666666667

# %%
print('The f1_score of the Decision Tree is',f1_score(test_y, prediction1, average='weighted'))
# Out:
# The f1_score of the Decision Tree is 0.7275197864561103

# %% [markdown]
# ### Random Forests

# %%
model=RandomForestClassifier(n_estimators=100)
model.fit(train_X,train_y)
prediction2=model.predict(test_X)
print("The prediction values are: ",prediction2)
# Out:
# The prediction values are:  [0 0 0 ... 1 0 0]

# %%
print('The accuracy of the Random Forests is',metrics.accuracy_score(prediction2,test_y))
# Out:
# The accuracy of the Random Forests is 0.818

# %%
print('The f1_score of the Random Forests is',f1_score(prediction2,test_y,average='weighted'))
# Out:
# The f1_score of the Random Forests is 0.8372847751898732

# %% [markdown]
# ### Linear Regression

# %%
reg = LinearRegression().fit(train_X, train_y)
print("The linear regression coefficients are: ",reg.coef_)
# Out:
# The linear regression coefficients are:  [-9.43523870e-08 -1.30701702e-02 -1.72740744e-02 -2.13826679e-02
#   1.37476684e-03  9.45036240e-02  2.02091279e-02  1.03457342e-02
#   3.05035440e-03  8.37385734e-03  8.02035622e-04 -6.63081950e-07
#   2.14065826e-07  6.23819131e-08 -1.78577850e-07  5.23230468e-08
#   7.41100893e-08 -7.93975229e-07 -9.25964622e-08 -1.64330414e-07
#  -3.22310409e-07 -3.74851315e-07 -1.47434982e-07]

# %%
print("The linear regression intercepion is: ",reg.intercept_)
# Out:
# The linear regression intercepion is:  0.3168826296206786

# %%
prediction4=reg.predict(test_X)

# %%
prediction4
# Out:
# array([ 0.23265229,  0.2792417 ,  0.04248709, ...,  0.45631349,
#        -0.02435364,  0.26787989])

# %%
regprediction=[]
for pre in prediction4:
    if pre>0.6:
        regprediction.append(1)
    else:
        regprediction.append(0)

# %%
print('The accuracy of the Linear Regression is',reg.score(test_X,test_y))
# Out:
# The accuracy of the Linear Regression is 0.11781360842609767

# %%
print('The f1_score of the Linear Regression is',f1_score(regprediction,test_y,average='weighted'))
# Out:
# The f1_score of the Linear Regression is 0.868094819925381

# %% [markdown]
# ### Logistic Regression

# %%
clf = LogisticRegression(random_state=0).fit(train_X, train_y)
print("The prediction values are: ",clf.predict(test_X))
# Out:
# The prediction values are:  [0 0 0 ... 0 0 0]

# %%
# Probability of defualt and non-defaultproba=clf.predict_proba(test_X) 
default_proba = []
for line in clf.predict_proba(test_X):
    default_proba.append(line[1])
    
print("The prediction default probabilities are: ",default_proba[0:5],'...')
# Out:
# The prediction default probabilities are:  [0.3034003373756001, 0.15642052588017283, 0.0071208232275463265, 0.3459029366799642, 0.3575755136835718] ...

# %%
print('The accuracy of the Logistic Regression is',clf.score(test_X, test_y))
# Out:
# The accuracy of the Logistic Regression is 0.7786666666666666

# %%
prediction3=clf.predict(test_X)
print("The prediction values are: ",prediction3)
print('The f1_score of the Logistuc Regression is',f1_score(prediction3,test_y,average='weighted'))
# Out:
# The prediction values are:  [0 0 0 ... 0 0 0]
# The f1_score of the Logistuc Regression is 0.875416291854073

# %%
flatten_data = prediction3.flatten()
list_data = flatten_data.tolist()
set_data = set(list_data)
set_data
# Out:
# {0, 1}

# %%
prediction3
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# ### XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(train_X, train_y)
print(accuracy_score(test_y, xgb.predict(test_X)))
# Out:
# 0.8166666666666667

# %%
print('The f1_score of  XGBClassifier is',f1_score(xgb.predict(test_X),test_y,average='weighted'))
# Out:
# The f1_score of  XGBClassifier is 0.8357195767195765

# %%
# importances = xgb.feature_importances_
# indices = np.argsort(importances)[::-1]
# names = [train_X.columns[i] for i in indices]
# plt.figure(figsize=(30,15))
# plt.title("Feature Importance")
# plt.bar(range(train_X.shape[1]), importances[indices])
# plt.xticks(range(train_X.shape[1]), names, rotation=90)
# plt.show()

# %% [markdown]
# ### CatBoost

# %%
cat = CatBoostClassifier()
cat.fit(train_X, train_y)
#print(accuracy_score(test_y, cat.predict(test_X)))

print('The f1_score of CatBoost is',f1_score(cat.predict(test_X),test_y,average='weighted'))
# Out:
# Learning rate set to 0.040021
# 0:	learn: 0.6702434	total: 70.6ms	remaining: 1m 10s
# 1:	learn: 0.6494491	total: 74.8ms	remaining: 37.3s
# 2:	learn: 0.6307258	total: 78.7ms	remaining: 26.2s
# 3:	learn: 0.6133443	total: 82.3ms	remaining: 20.5s
# 4:	learn: 0.5984949	total: 86ms	remaining: 17.1s
# 5:	learn: 0.5839116	total: 90ms	remaining: 14.9s
# 6:	learn: 0.5708195	total: 94.3ms	remaining: 13.4s
# 7:	learn: 0.5592621	total: 98.4ms	remaining: 12.2s
# 8:	learn: 0.5485008	total: 103ms	remaining: 11.3s
# 9:	learn: 0.5390985	total: 107ms	remaining: 10.6s
# 10:	learn: 0.5303422	total: 111ms	remaining: 9.94s
# 11:	learn: 0.5223826	total: 115ms	remaining: 9.43s
# 12:	learn: 0.5147679	total: 118ms	remaining: 8.99s
# 13:	learn: 0.5077507	total: 122ms	remaining: 8.6s
# 14:	learn: 0.5016808	total: 126ms	remaining: 8.29s
# 15:	learn: 0.4959133	total: 130ms	remaining: 8.02s
# 16:	learn: 0.4906572	total: 135ms	remaining: 7.79s
# 17:	learn: 0.4858058	total: 140ms	remaining: 7.64s
# 18:	learn: 0.4812640	total: 147ms	remaining: 7.59s
# 19:	learn: 0.4772892	total: 153ms	remaining: 7.49s
# 20:	learn: 0.4733886	total: 158ms	remaining: 7.36s
# 21:	learn: 0.4699980	total: 164ms	remaining: 7.28s
# 22:	learn: 0.4669311	total: 169ms	remaining: 7.19s
# 23:	learn: 0.4640532	total: 175ms	remaining: 7.1s
# 24:	learn: 0.4615630	total: 180ms	remaining: 7.01s
# 25:	learn: 0.4591876	total: 185ms	remaining: 6.95s
# 26:	learn: 0.4568469	total: 191ms	remaining: 6.88s
# 27:	learn: 0.4545851	total: 200ms	remaining: 6.93s
# 28:	learn: 0.4527285	total: 211ms	remaining: 7.06s
# 29:	learn: 0.4508249	total: 218ms	remaining: 7.04s
# 30:	learn: 0.4490236	total: 222ms	remaining: 6.95s
# 31:	learn: 0.4475473	total: 227ms	remaining: 6.88s
# 32:	learn: 0.4460832	total: 232ms	remaining: 6.8s
# 33:	learn: 0.4447541	total: 237ms	remaining: 6.73s
# 34:	learn: 0.4432308	total: 242ms	remaining: 6.67s
# 35:	learn: 0.4421322	total: 246ms	remaining: 6.59s
# 36:	learn: 0.4410468	total: 252ms	remaining: 6.55s
# 37:	learn: 0.4400230	total: 257ms	remaining: 6.51s
# 38:	learn: 0.4389216	total: 264ms	remaining: 6.5s
# 39:	learn: 0.4380256	total: 269ms	remaining: 6.45s
# 40:	learn: 0.4372490	total: 273ms	remaining: 6.4s
# 41:	learn: 0.4363348	total: 279ms	remaining: 6.37s
# 42:	learn: 0.4356088	total: 284ms	remaining: 6.32s
# 43:	learn: 0.4349112	total: 291ms	remaining: 6.33s
# 44:	learn: 0.4342277	total: 298ms	remaining: 6.32s
# 45:	learn: 0.4337012	total: 303ms	remaining: 6.29s
# 46:	learn: 0.4332248	total: 309ms	remaining: 6.26s
# 47:	learn: 0.4326970	total: 315ms	remaining: 6.25s
# 48:	learn: 0.4322140	total: 322ms	remaining: 6.24s
# 49:	learn: 0.4316265	total: 347ms	remaining: 6.6s
# 50:	learn: 0.4311023	total: 360ms	remaining: 6.7s
# 51:	learn: 0.4306623	total: 372ms	remaining: 6.78s
# 52:	learn: 0.4302963	total: 384ms	remaining: 6.87s
# 53:	learn: 0.4298791	total: 403ms	remaining: 7.06s
# 54:	learn: 0.4294894	total: 415ms	remaining: 7.13s
# 55:	learn: 0.4290899	total: 436ms	remaining: 7.35s
# 56:	learn: 0.4287059	total: 448ms	remaining: 7.41s
# 57:	learn: 0.4285286	total: 455ms	remaining: 7.39s
# 58:	learn: 0.4281999	total: 466ms	remaining: 7.43s
# 59:	learn: 0.4279342	total: 477ms	remaining: 7.47s
# 60:	learn: 0.4276559	total: 487ms	remaining: 7.5s
# 61:	learn: 0.4274018	total: 509ms	remaining: 7.69s
# 62:	learn: 0.4271719	total: 520ms	remaining: 7.74s
# 63:	learn: 0.4268931	total: 533ms	remaining: 7.8s
# 64:	learn: 0.4266508	total: 553ms	remaining: 7.95s
# 65:	learn: 0.4264017	total: 567ms	remaining: 8.02s
# 66:	learn: 0.4261383	total: 584ms	remaining: 8.13s
# 67:	learn: 0.4259433	total: 590ms	remaining: 8.08s
# 68:	learn: 0.4257714	total: 595ms	remaining: 8.03s
# 69:	learn: 0.4255153	total: 600ms	remaining: 7.97s
# 70:	learn: 0.4253093	total: 606ms	remaining: 7.92s
# 71:	learn: 0.4251396	total: 611ms	remaining: 7.88s
# 72:	learn: 0.4249959	total: 616ms	remaining: 7.82s
# 73:	learn: 0.4248678	total: 622ms	remaining: 7.78s
# 74:	learn: 0.4245886	total: 628ms	remaining: 7.75s
# 75:	learn: 0.4243952	total: 634ms	remaining: 7.71s
# 76:	learn: 0.4241888	total: 640ms	remaining: 7.67s
# 77:	learn: 0.4239505	total: 646ms	remaining: 7.63s
# 78:	learn: 0.4236810	total: 652ms	remaining: 7.61s
# 79:	learn: 0.4235683	total: 658ms	remaining: 7.56s
# 80:	learn: 0.4233347	total: 663ms	remaining: 7.52s
# 81:	learn: 0.4231592	total: 670ms	remaining: 7.5s
# 82:	learn: 0.4229794	total: 675ms	remaining: 7.46s
# 83:	learn: 0.4227427	total: 680ms	remaining: 7.42s
# 84:	learn: 0.4225415	total: 686ms	remaining: 7.38s
# 85:	learn: 0.4223170	total: 691ms	remaining: 7.34s
# 86:	learn: 0.4221998	total: 695ms	remaining: 7.3s
# 87:	learn: 0.4220675	total: 700ms	remaining: 7.25s
# 88:	learn: 0.4219514	total: 705ms	remaining: 7.21s
# 89:	learn: 0.4218142	total: 710ms	remaining: 7.18s
# 90:	learn: 0.4216294	total: 716ms	remaining: 7.15s
# 91:	learn: 0.4214800	total: 721ms	remaining: 7.11s
# 92:	learn: 0.4212912	total: 726ms	remaining: 7.08s
# 93:	learn: 0.4211536	total: 731ms	remaining: 7.05s
# 94:	learn: 0.4209911	total: 736ms	remaining: 7.01s
# 95:	learn: 0.4208177	total: 741ms	remaining: 6.97s
# 96:	learn: 0.4207124	total: 747ms	remaining: 6.95s
# 97:	learn: 0.4205959	total: 752ms	remaining: 6.92s
# 98:	learn: 0.4204492	total: 758ms	remaining: 6.89s
# 99:	learn: 0.4202529	total: 763ms	remaining: 6.86s
# 100:	learn: 0.4200656	total: 768ms	remaining: 6.83s
# 101:	learn: 0.4198653	total: 772ms	remaining: 6.8s
# 102:	learn: 0.4197373	total: 777ms	remaining: 6.76s
# 103:	learn: 0.4195880	total: 782ms	remaining: 6.74s
# 104:	learn: 0.4194642	total: 787ms	remaining: 6.71s
# 105:	learn: 0.4193427	total: 792ms	remaining: 6.68s
# 106:	learn: 0.4192434	total: 797ms	remaining: 6.65s
# 107:	learn: 0.4191153	total: 802ms	remaining: 6.62s
# 108:	learn: 0.4189377	total: 807ms	remaining: 6.6s
# 109:	learn: 0.4188315	total: 812ms	remaining: 6.57s
# 110:	learn: 0.4186601	total: 818ms	remaining: 6.55s
# 111:	learn: 0.4185812	total: 824ms	remaining: 6.53s
# 112:	learn: 0.4184799	total: 829ms	remaining: 6.51s
# 113:	learn: 0.4183566	total: 835ms	remaining: 6.49s
# 114:	learn: 0.4182394	total: 841ms	remaining: 6.47s
# 115:	learn: 0.4181219	total: 847ms	remaining: 6.46s
# 116:	learn: 0.4180596	total: 852ms	remaining: 6.43s
# 117:	learn: 0.4179396	total: 857ms	remaining: 6.41s
# 118:	learn: 0.4178046	total: 862ms	remaining: 6.38s
# 119:	learn: 0.4177203	total: 867ms	remaining: 6.36s
# 120:	learn: 0.4176512	total: 871ms	remaining: 6.33s
# 121:	learn: 0.4175222	total: 876ms	remaining: 6.3s
# 122:	learn: 0.4174272	total: 881ms	remaining: 6.28s
# 123:	learn: 0.4172861	total: 886ms	remaining: 6.26s
# 124:	learn: 0.4171791	total: 891ms	remaining: 6.24s
# 125:	learn: 0.4170555	total: 897ms	remaining: 6.22s
# 126:	learn: 0.4169401	total: 902ms	remaining: 6.2s
# 127:	learn: 0.4168306	total: 907ms	remaining: 6.18s
# 128:	learn: 0.4167114	total: 916ms	remaining: 6.18s
# 129:	learn: 0.4165896	total: 921ms	remaining: 6.16s
# 130:	learn: 0.4165152	total: 929ms	remaining: 6.16s
# 131:	learn: 0.4164441	total: 934ms	remaining: 6.14s
# 132:	learn: 0.4163189	total: 939ms	remaining: 6.12s
# 133:	learn: 0.4162172	total: 943ms	remaining: 6.09s
# 134:	learn: 0.4161101	total: 948ms	remaining: 6.07s
# 135:	learn: 0.4159914	total: 953ms	remaining: 6.05s
# 136:	learn: 0.4158518	total: 957ms	remaining: 6.03s
# 137:	learn: 0.4157124	total: 962ms	remaining: 6.01s
# 138:	learn: 0.4156039	total: 967ms	remaining: 5.99s
# 139:	learn: 0.4155089	total: 972ms	remaining: 5.97s
# 140:	learn: 0.4153759	total: 977ms	remaining: 5.95s
# 141:	learn: 0.4153171	total: 982ms	remaining: 5.93s
# 142:	learn: 0.4151777	total: 987ms	remaining: 5.91s
# 143:	learn: 0.4151129	total: 991ms	remaining: 5.89s
# 144:	learn: 0.4149790	total: 996ms	remaining: 5.87s
# 145:	learn: 0.4148668	total: 1s	remaining: 5.85s
# 146:	learn: 0.4148173	total: 1s	remaining: 5.83s
# 147:	learn: 0.4146120	total: 1.01s	remaining: 5.81s
# 148:	learn: 0.4144516	total: 1.01s	remaining: 5.79s
# 149:	learn: 0.4143116	total: 1.02s	remaining: 5.77s
# 150:	learn: 0.4142278	total: 1.02s	remaining: 5.76s
# 151:	learn: 0.4141543	total: 1.03s	remaining: 5.74s
# 152:	learn: 0.4140750	total: 1.03s	remaining: 5.72s
# 153:	learn: 0.4139680	total: 1.04s	remaining: 5.71s
# 154:	learn: 0.4138372	total: 1.04s	remaining: 5.69s
# 155:	learn: 0.4137701	total: 1.05s	remaining: 5.68s
# 156:	learn: 0.4136655	total: 1.05s	remaining: 5.66s
# 157:	learn: 0.4135203	total: 1.06s	remaining: 5.64s
# 158:	learn: 0.4133589	total: 1.06s	remaining: 5.62s
# 159:	learn: 0.4132549	total: 1.07s	remaining: 5.61s
# 160:	learn: 0.4131247	total: 1.07s	remaining: 5.59s
# 161:	learn: 0.4130385	total: 1.08s	remaining: 5.58s
# 162:	learn: 0.4129521	total: 1.08s	remaining: 5.56s
# 163:	learn: 0.4128563	total: 1.09s	remaining: 5.55s
# 164:	learn: 0.4127918	total: 1.09s	remaining: 5.53s
# 165:	learn: 0.4126507	total: 1.1s	remaining: 5.52s
# 166:	learn: 0.4125496	total: 1.1s	remaining: 5.5s
# 167:	learn: 0.4124679	total: 1.11s	remaining: 5.49s
# 168:	learn: 0.4123204	total: 1.11s	remaining: 5.47s
# 169:	learn: 0.4122172	total: 1.12s	remaining: 5.46s
# 170:	learn: 0.4121157	total: 1.12s	remaining: 5.44s
# 171:	learn: 0.4119988	total: 1.13s	remaining: 5.43s
# 172:	learn: 0.4119454	total: 1.14s	remaining: 5.43s
# 173:	learn: 0.4118505	total: 1.14s	remaining: 5.41s
# 174:	learn: 0.4117034	total: 1.14s	remaining: 5.4s
# 175:	learn: 0.4115679	total: 1.15s	remaining: 5.38s
# 176:	learn: 0.4114389	total: 1.15s	remaining: 5.37s
# 177:	learn: 0.4113487	total: 1.16s	remaining: 5.35s
# 178:	learn: 0.4112566	total: 1.16s	remaining: 5.34s
# 179:	learn: 0.4111831	total: 1.17s	remaining: 5.33s
# 180:	learn: 0.4110986	total: 1.17s	remaining: 5.31s
# 181:	learn: 0.4109870	total: 1.18s	remaining: 5.3s
# 182:	learn: 0.4108458	total: 1.18s	remaining: 5.29s
# 183:	learn: 0.4107303	total: 1.19s	remaining: 5.28s
# 184:	learn: 0.4106334	total: 1.19s	remaining: 5.26s
# 185:	learn: 0.4105454	total: 1.2s	remaining: 5.25s
# 186:	learn: 0.4104547	total: 1.2s	remaining: 5.23s
# 187:	learn: 0.4103046	total: 1.21s	remaining: 5.22s
# 188:	learn: 0.4102149	total: 1.21s	remaining: 5.21s
# 189:	learn: 0.4101229	total: 1.22s	remaining: 5.19s
# 190:	learn: 0.4100567	total: 1.22s	remaining: 5.18s
# 191:	learn: 0.4099141	total: 1.23s	remaining: 5.17s
# 192:	learn: 0.4098636	total: 1.23s	remaining: 5.16s
# 193:	learn: 0.4097645	total: 1.24s	remaining: 5.14s
# 194:	learn: 0.4096763	total: 1.24s	remaining: 5.13s
# 195:	learn: 0.4095777	total: 1.25s	remaining: 5.12s
# 196:	learn: 0.4095235	total: 1.25s	remaining: 5.11s
# 197:	learn: 0.4094708	total: 1.26s	remaining: 5.1s
# 198:	learn: 0.4093747	total: 1.26s	remaining: 5.09s
# 199:	learn: 0.4092627	total: 1.27s	remaining: 5.08s
# 200:	learn: 0.4091827	total: 1.27s	remaining: 5.06s
# 201:	learn: 0.4091133	total: 1.28s	remaining: 5.05s
# 202:	learn: 0.4090038	total: 1.28s	remaining: 5.04s
# 203:	learn: 0.4089404	total: 1.29s	remaining: 5.03s
# 204:	learn: 0.4088380	total: 1.29s	remaining: 5.02s
# 205:	learn: 0.4087439	total: 1.3s	remaining: 5.01s
# 206:	learn: 0.4086403	total: 1.3s	remaining: 5s
# 207:	learn: 0.4085496	total: 1.31s	remaining: 4.99s
# 208:	learn: 0.4084183	total: 1.31s	remaining: 4.98s
# 209:	learn: 0.4082966	total: 1.32s	remaining: 4.97s
# 210:	learn: 0.4082184	total: 1.32s	remaining: 4.96s
# 211:	learn: 0.4081435	total: 1.33s	remaining: 4.94s
# 212:	learn: 0.4080923	total: 1.33s	remaining: 4.93s
# 213:	learn: 0.4080267	total: 1.34s	remaining: 4.92s
# 214:	learn: 0.4079235	total: 1.34s	remaining: 4.91s
# 215:	learn: 0.4077922	total: 1.35s	remaining: 4.89s
# 216:	learn: 0.4077468	total: 1.35s	remaining: 4.88s
# 217:	learn: 0.4076598	total: 1.36s	remaining: 4.87s
# 218:	learn: 0.4075773	total: 1.36s	remaining: 4.86s
# 219:	learn: 0.4074993	total: 1.37s	remaining: 4.85s
# 220:	learn: 0.4074411	total: 1.37s	remaining: 4.84s
# 221:	learn: 0.4073242	total: 1.38s	remaining: 4.83s
# 222:	learn: 0.4072431	total: 1.38s	remaining: 4.82s
# 223:	learn: 0.4071154	total: 1.39s	remaining: 4.81s
# 224:	learn: 0.4070371	total: 1.39s	remaining: 4.79s
# 225:	learn: 0.4069759	total: 1.4s	remaining: 4.78s
# 226:	learn: 0.4069260	total: 1.4s	remaining: 4.77s
# 227:	learn: 0.4068618	total: 1.41s	remaining: 4.76s
# 228:	learn: 0.4068101	total: 1.41s	remaining: 4.75s
# 229:	learn: 0.4067249	total: 1.42s	remaining: 4.74s
# 230:	learn: 0.4066537	total: 1.42s	remaining: 4.73s
# 231:	learn: 0.4065870	total: 1.43s	remaining: 4.72s
# 232:	learn: 0.4065039	total: 1.43s	remaining: 4.71s
# 233:	learn: 0.4064151	total: 1.44s	remaining: 4.7s
# 234:	learn: 0.4063643	total: 1.44s	remaining: 4.69s
# 235:	learn: 0.4062264	total: 1.45s	remaining: 4.68s
# 236:	learn: 0.4061425	total: 1.45s	remaining: 4.67s
# 237:	learn: 0.4060494	total: 1.46s	remaining: 4.66s
# 238:	learn: 0.4058942	total: 1.46s	remaining: 4.65s
# 239:	learn: 0.4057921	total: 1.47s	remaining: 4.64s
# 240:	learn: 0.4057055	total: 1.47s	remaining: 4.63s
# 241:	learn: 0.4056093	total: 1.48s	remaining: 4.62s
# 242:	learn: 0.4055109	total: 1.48s	remaining: 4.61s
# 243:	learn: 0.4053729	total: 1.49s	remaining: 4.6s
# 244:	learn: 0.4052419	total: 1.49s	remaining: 4.6s
# 245:	learn: 0.4051105	total: 1.5s	remaining: 4.59s
# 246:	learn: 0.4050312	total: 1.5s	remaining: 4.58s
# 247:	learn: 0.4048931	total: 1.51s	remaining: 4.57s
# 248:	learn: 0.4047979	total: 1.51s	remaining: 4.56s
# 249:	learn: 0.4046500	total: 1.52s	remaining: 4.55s
# 250:	learn: 0.4045403	total: 1.52s	remaining: 4.54s
# 251:	learn: 0.4044190	total: 1.53s	remaining: 4.53s
# 252:	learn: 0.4042725	total: 1.53s	remaining: 4.52s
# 253:	learn: 0.4041378	total: 1.53s	remaining: 4.51s
# 254:	learn: 0.4040035	total: 1.54s	remaining: 4.5s
# 255:	learn: 0.4039102	total: 1.54s	remaining: 4.49s
# 256:	learn: 0.4037723	total: 1.55s	remaining: 4.48s
# 257:	learn: 0.4037013	total: 1.55s	remaining: 4.47s
# 258:	learn: 0.4035738	total: 1.56s	remaining: 4.46s
# 259:	learn: 0.4034364	total: 1.56s	remaining: 4.45s
# 260:	learn: 0.4033265	total: 1.57s	remaining: 4.45s
# 261:	learn: 0.4032640	total: 1.57s	remaining: 4.43s
# 262:	learn: 0.4031455	total: 1.58s	remaining: 4.42s
# 263:	learn: 0.4030485	total: 1.58s	remaining: 4.42s
# 264:	learn: 0.4029700	total: 1.59s	remaining: 4.41s
# 265:	learn: 0.4028683	total: 1.59s	remaining: 4.4s
# 266:	learn: 0.4027721	total: 1.6s	remaining: 4.39s
# 267:	learn: 0.4026850	total: 1.6s	remaining: 4.38s
# 268:	learn: 0.4025701	total: 1.61s	remaining: 4.37s
# 269:	learn: 0.4025076	total: 1.61s	remaining: 4.36s
# 270:	learn: 0.4024070	total: 1.62s	remaining: 4.35s
# 271:	learn: 0.4022932	total: 1.62s	remaining: 4.34s
# 272:	learn: 0.4022230	total: 1.63s	remaining: 4.33s
# 273:	learn: 0.4020935	total: 1.63s	remaining: 4.33s
# 274:	learn: 0.4020230	total: 1.64s	remaining: 4.32s
# 275:	learn: 0.4019548	total: 1.64s	remaining: 4.31s
# 276:	learn: 0.4018670	total: 1.65s	remaining: 4.3s
# 277:	learn: 0.4017916	total: 1.65s	remaining: 4.29s
# 278:	learn: 0.4016948	total: 1.66s	remaining: 4.28s
# 279:	learn: 0.4015312	total: 1.66s	remaining: 4.28s
# 280:	learn: 0.4014284	total: 1.67s	remaining: 4.27s
# 281:	learn: 0.4013148	total: 1.67s	remaining: 4.26s
# 282:	learn: 0.4011947	total: 1.68s	remaining: 4.25s
# 283:	learn: 0.4010887	total: 1.68s	remaining: 4.24s
# 284:	learn: 0.4010148	total: 1.69s	remaining: 4.23s
# 285:	learn: 0.4008786	total: 1.69s	remaining: 4.22s
# 286:	learn: 0.4008044	total: 1.7s	remaining: 4.21s
# 287:	learn: 0.4007105	total: 1.7s	remaining: 4.21s
# 288:	learn: 0.4005642	total: 1.71s	remaining: 4.2s
# 289:	learn: 0.4004527	total: 1.71s	remaining: 4.19s
# 290:	learn: 0.4003771	total: 1.72s	remaining: 4.18s
# 291:	learn: 0.4002694	total: 1.72s	remaining: 4.17s
# 292:	learn: 0.4001977	total: 1.73s	remaining: 4.17s
# 293:	learn: 0.4000954	total: 1.73s	remaining: 4.16s
# 294:	learn: 0.3999961	total: 1.74s	remaining: 4.15s
# 295:	learn: 0.3998732	total: 1.74s	remaining: 4.14s
# 296:	learn: 0.3997695	total: 1.75s	remaining: 4.13s
# 297:	learn: 0.3996643	total: 1.75s	remaining: 4.12s
# 298:	learn: 0.3995662	total: 1.75s	remaining: 4.12s
# 299:	learn: 0.3994706	total: 1.76s	remaining: 4.11s
# 300:	learn: 0.3993811	total: 1.76s	remaining: 4.1s
# 301:	learn: 0.3992854	total: 1.77s	remaining: 4.09s
# 302:	learn: 0.3992234	total: 1.77s	remaining: 4.08s
# 303:	learn: 0.3991579	total: 1.78s	remaining: 4.07s
# 304:	learn: 0.3990355	total: 1.78s	remaining: 4.07s
# 305:	learn: 0.3989409	total: 1.79s	remaining: 4.06s
# 306:	learn: 0.3987890	total: 1.79s	remaining: 4.05s
# 307:	learn: 0.3986463	total: 1.8s	remaining: 4.04s
# 308:	learn: 0.3985172	total: 1.8s	remaining: 4.04s
# 309:	learn: 0.3984287	total: 1.81s	remaining: 4.03s
# 310:	learn: 0.3983195	total: 1.81s	remaining: 4.02s
# 311:	learn: 0.3981582	total: 1.82s	remaining: 4.01s
# 312:	learn: 0.3981102	total: 1.82s	remaining: 4s
# 313:	learn: 0.3980255	total: 1.83s	remaining: 4s
# 314:	learn: 0.3978994	total: 1.83s	remaining: 3.99s
# 315:	learn: 0.3977964	total: 1.84s	remaining: 3.98s
# 316:	learn: 0.3976719	total: 1.84s	remaining: 3.97s
# 317:	learn: 0.3975812	total: 1.85s	remaining: 3.97s
# 318:	learn: 0.3974676	total: 1.85s	remaining: 3.96s
# 319:	learn: 0.3973612	total: 1.86s	remaining: 3.95s
# 320:	learn: 0.3972079	total: 1.86s	remaining: 3.94s
# 321:	learn: 0.3971329	total: 1.87s	remaining: 3.93s
# 322:	learn: 0.3970130	total: 1.87s	remaining: 3.93s
# 323:	learn: 0.3969161	total: 1.88s	remaining: 3.92s
# 324:	learn: 0.3968368	total: 1.88s	remaining: 3.91s
# 325:	learn: 0.3967343	total: 1.89s	remaining: 3.9s
# 326:	learn: 0.3965923	total: 1.89s	remaining: 3.9s
# 327:	learn: 0.3965329	total: 1.9s	remaining: 3.89s
# 328:	learn: 0.3963760	total: 1.9s	remaining: 3.88s
# 329:	learn: 0.3962336	total: 1.91s	remaining: 3.88s
# 330:	learn: 0.3961060	total: 1.91s	remaining: 3.87s
# 331:	learn: 0.3959763	total: 1.92s	remaining: 3.86s
# 332:	learn: 0.3959027	total: 1.92s	remaining: 3.85s
# 333:	learn: 0.3957953	total: 1.93s	remaining: 3.85s
# 334:	learn: 0.3956659	total: 1.93s	remaining: 3.84s
# 335:	learn: 0.3955255	total: 1.94s	remaining: 3.83s
# 336:	learn: 0.3954346	total: 1.94s	remaining: 3.83s
# 337:	learn: 0.3952987	total: 1.95s	remaining: 3.82s
# 338:	learn: 0.3952355	total: 1.95s	remaining: 3.81s
# 339:	learn: 0.3951557	total: 1.96s	remaining: 3.8s
# 340:	learn: 0.3950176	total: 1.96s	remaining: 3.8s
# 341:	learn: 0.3949010	total: 1.97s	remaining: 3.79s
# 342:	learn: 0.3947620	total: 1.98s	remaining: 3.78s
# 343:	learn: 0.3946722	total: 1.98s	remaining: 3.78s
# 344:	learn: 0.3945944	total: 1.99s	remaining: 3.77s
# 345:	learn: 0.3944836	total: 1.99s	remaining: 3.76s
# 346:	learn: 0.3944330	total: 2s	remaining: 3.75s
# 347:	learn: 0.3943282	total: 2s	remaining: 3.75s
# 348:	learn: 0.3941888	total: 2s	remaining: 3.74s
# 349:	learn: 0.3940606	total: 2.01s	remaining: 3.73s
# 350:	learn: 0.3939433	total: 2.01s	remaining: 3.73s
# 351:	learn: 0.3938106	total: 2.02s	remaining: 3.72s
# 352:	learn: 0.3937169	total: 2.03s	remaining: 3.71s
# 353:	learn: 0.3936433	total: 2.03s	remaining: 3.71s
# 354:	learn: 0.3935442	total: 2.04s	remaining: 3.7s
# 355:	learn: 0.3934587	total: 2.04s	remaining: 3.69s
# 356:	learn: 0.3933592	total: 2.05s	remaining: 3.69s
# 357:	learn: 0.3933138	total: 2.05s	remaining: 3.68s
# 358:	learn: 0.3931859	total: 2.06s	remaining: 3.67s
# 359:	learn: 0.3930783	total: 2.06s	remaining: 3.66s
# 360:	learn: 0.3929487	total: 2.07s	remaining: 3.66s
# 361:	learn: 0.3927880	total: 2.07s	remaining: 3.65s
# 362:	learn: 0.3926725	total: 2.08s	remaining: 3.65s
# 363:	learn: 0.3925718	total: 2.08s	remaining: 3.64s
# 364:	learn: 0.3924643	total: 2.09s	remaining: 3.63s
# 365:	learn: 0.3923544	total: 2.09s	remaining: 3.62s
# 366:	learn: 0.3922643	total: 2.1s	remaining: 3.62s
# 367:	learn: 0.3922216	total: 2.1s	remaining: 3.61s
# 368:	learn: 0.3921344	total: 2.11s	remaining: 3.6s
# 369:	learn: 0.3920075	total: 2.11s	remaining: 3.6s
# 370:	learn: 0.3918761	total: 2.12s	remaining: 3.59s
# 371:	learn: 0.3917502	total: 2.13s	remaining: 3.59s
# 372:	learn: 0.3916879	total: 2.13s	remaining: 3.58s
# 373:	learn: 0.3915690	total: 2.14s	remaining: 3.58s
# 374:	learn: 0.3914563	total: 2.14s	remaining: 3.57s
# 375:	learn: 0.3913707	total: 2.15s	remaining: 3.56s
# 376:	learn: 0.3912863	total: 2.15s	remaining: 3.56s
# 377:	learn: 0.3912084	total: 2.16s	remaining: 3.55s
# 378:	learn: 0.3911747	total: 2.16s	remaining: 3.54s
# 379:	learn: 0.3910997	total: 2.17s	remaining: 3.53s
# 380:	learn: 0.3909276	total: 2.17s	remaining: 3.53s
# 381:	learn: 0.3908445	total: 2.18s	remaining: 3.52s
# 382:	learn: 0.3907705	total: 2.18s	remaining: 3.52s
# 383:	learn: 0.3906770	total: 2.19s	remaining: 3.51s
# 384:	learn: 0.3905683	total: 2.2s	remaining: 3.51s
# 385:	learn: 0.3904884	total: 2.21s	remaining: 3.51s
# 386:	learn: 0.3904386	total: 2.21s	remaining: 3.51s
# 387:	learn: 0.3903555	total: 2.22s	remaining: 3.5s
# 388:	learn: 0.3902570	total: 2.23s	remaining: 3.51s
# 389:	learn: 0.3901601	total: 2.24s	remaining: 3.51s
# 390:	learn: 0.3900604	total: 2.25s	remaining: 3.51s
# 391:	learn: 0.3899185	total: 2.27s	remaining: 3.51s
# 392:	learn: 0.3898213	total: 2.27s	remaining: 3.51s
# 393:	learn: 0.3897367	total: 2.28s	remaining: 3.51s
# 394:	learn: 0.3896782	total: 2.29s	remaining: 3.51s
# 395:	learn: 0.3895395	total: 2.3s	remaining: 3.51s
# 396:	learn: 0.3894711	total: 2.31s	remaining: 3.51s
# 397:	learn: 0.3894036	total: 2.32s	remaining: 3.51s
# 398:	learn: 0.3893574	total: 2.33s	remaining: 3.5s
# 399:	learn: 0.3893214	total: 2.34s	remaining: 3.5s
# 400:	learn: 0.3892208	total: 2.35s	remaining: 3.51s
# 401:	learn: 0.3891257	total: 2.36s	remaining: 3.51s
# 402:	learn: 0.3890456	total: 2.37s	remaining: 3.5s
# 403:	learn: 0.3888767	total: 2.38s	remaining: 3.51s
# 404:	learn: 0.3888247	total: 2.39s	remaining: 3.51s
# 405:	learn: 0.3886786	total: 2.4s	remaining: 3.51s
# 406:	learn: 0.3885302	total: 2.41s	remaining: 3.51s
# 407:	learn: 0.3884219	total: 2.41s	remaining: 3.5s
# 408:	learn: 0.3882773	total: 2.42s	remaining: 3.5s
# 409:	learn: 0.3881941	total: 2.42s	remaining: 3.49s
# 410:	learn: 0.3881410	total: 2.43s	remaining: 3.48s
# 411:	learn: 0.3879946	total: 2.44s	remaining: 3.48s
# 412:	learn: 0.3879421	total: 2.44s	remaining: 3.47s
# 413:	learn: 0.3878378	total: 2.45s	remaining: 3.46s
# 414:	learn: 0.3877732	total: 2.45s	remaining: 3.46s
# 415:	learn: 0.3877135	total: 2.46s	remaining: 3.45s
# 416:	learn: 0.3876934	total: 2.46s	remaining: 3.44s
# 417:	learn: 0.3876142	total: 2.47s	remaining: 3.44s
# 418:	learn: 0.3874912	total: 2.47s	remaining: 3.43s
# 419:	learn: 0.3874266	total: 2.48s	remaining: 3.42s
# 420:	learn: 0.3873067	total: 2.48s	remaining: 3.42s
# 421:	learn: 0.3872581	total: 2.49s	remaining: 3.41s
# 422:	learn: 0.3871686	total: 2.49s	remaining: 3.4s
# 423:	learn: 0.3870307	total: 2.5s	remaining: 3.4s
# 424:	learn: 0.3869102	total: 2.5s	remaining: 3.39s
# 425:	learn: 0.3868007	total: 2.51s	remaining: 3.38s
# 426:	learn: 0.3867419	total: 2.52s	remaining: 3.38s
# 427:	learn: 0.3865789	total: 2.52s	remaining: 3.37s
# 428:	learn: 0.3864984	total: 2.53s	remaining: 3.37s
# 429:	learn: 0.3863624	total: 2.53s	remaining: 3.36s
# 430:	learn: 0.3863039	total: 2.54s	remaining: 3.35s
# 431:	learn: 0.3862530	total: 2.54s	remaining: 3.34s
# 432:	learn: 0.3861684	total: 2.55s	remaining: 3.34s
# 433:	learn: 0.3860735	total: 2.55s	remaining: 3.33s
# 434:	learn: 0.3859616	total: 2.56s	remaining: 3.32s
# 435:	learn: 0.3858248	total: 2.56s	remaining: 3.32s
# 436:	learn: 0.3857479	total: 2.57s	remaining: 3.31s
# 437:	learn: 0.3856376	total: 2.57s	remaining: 3.3s
# 438:	learn: 0.3855485	total: 2.58s	remaining: 3.29s
# 439:	learn: 0.3854209	total: 2.58s	remaining: 3.29s
# 440:	learn: 0.3853304	total: 2.59s	remaining: 3.28s
# 441:	learn: 0.3852198	total: 2.59s	remaining: 3.27s
# 442:	learn: 0.3851127	total: 2.6s	remaining: 3.27s
# 443:	learn: 0.3849952	total: 2.6s	remaining: 3.26s
# 444:	learn: 0.3849087	total: 2.61s	remaining: 3.25s
# 445:	learn: 0.3847618	total: 2.61s	remaining: 3.24s
# 446:	learn: 0.3846791	total: 2.62s	remaining: 3.24s
# 447:	learn: 0.3846049	total: 2.62s	remaining: 3.23s
# 448:	learn: 0.3844846	total: 2.63s	remaining: 3.22s
# 449:	learn: 0.3843620	total: 2.63s	remaining: 3.22s
# 450:	learn: 0.3842170	total: 2.64s	remaining: 3.21s
# 451:	learn: 0.3841128	total: 2.64s	remaining: 3.2s
# 452:	learn: 0.3840169	total: 2.65s	remaining: 3.19s
# 453:	learn: 0.3839516	total: 2.65s	remaining: 3.19s
# 454:	learn: 0.3838540	total: 2.66s	remaining: 3.18s
# 455:	learn: 0.3837575	total: 2.66s	remaining: 3.17s
# 456:	learn: 0.3836678	total: 2.67s	remaining: 3.17s
# 457:	learn: 0.3835869	total: 2.67s	remaining: 3.16s
# 458:	learn: 0.3835038	total: 2.68s	remaining: 3.16s
# 459:	learn: 0.3834310	total: 2.68s	remaining: 3.15s
# 460:	learn: 0.3833740	total: 2.69s	remaining: 3.14s
# 461:	learn: 0.3833262	total: 2.69s	remaining: 3.14s
# 462:	learn: 0.3832240	total: 2.7s	remaining: 3.13s
# 463:	learn: 0.3831569	total: 2.71s	remaining: 3.13s
# 464:	learn: 0.3830342	total: 2.71s	remaining: 3.12s
# 465:	learn: 0.3829673	total: 2.71s	remaining: 3.11s
# 466:	learn: 0.3828593	total: 2.72s	remaining: 3.1s
# 467:	learn: 0.3827860	total: 2.73s	remaining: 3.1s
# 468:	learn: 0.3827156	total: 2.73s	remaining: 3.09s
# 469:	learn: 0.3825857	total: 2.73s	remaining: 3.08s
# 470:	learn: 0.3824693	total: 2.74s	remaining: 3.08s
# 471:	learn: 0.3823845	total: 2.74s	remaining: 3.07s
# 472:	learn: 0.3822565	total: 2.75s	remaining: 3.06s
# 473:	learn: 0.3821332	total: 2.75s	remaining: 3.06s
# 474:	learn: 0.3820629	total: 2.76s	remaining: 3.05s
# 475:	learn: 0.3819743	total: 2.76s	remaining: 3.04s
# 476:	learn: 0.3818690	total: 2.77s	remaining: 3.04s
# 477:	learn: 0.3817674	total: 2.77s	remaining: 3.03s
# 478:	learn: 0.3816593	total: 2.78s	remaining: 3.02s
# 479:	learn: 0.3815910	total: 2.79s	remaining: 3.02s
# 480:	learn: 0.3815259	total: 2.79s	remaining: 3.01s
# 481:	learn: 0.3813975	total: 2.8s	remaining: 3.01s
# 482:	learn: 0.3813152	total: 2.8s	remaining: 3s
# 483:	learn: 0.3811838	total: 2.81s	remaining: 2.99s
# 484:	learn: 0.3811101	total: 2.81s	remaining: 2.98s
# 485:	learn: 0.3810267	total: 2.82s	remaining: 2.98s
# 486:	learn: 0.3809443	total: 2.82s	remaining: 2.97s
# 487:	learn: 0.3808389	total: 2.83s	remaining: 2.96s
# 488:	learn: 0.3807892	total: 2.83s	remaining: 2.96s
# 489:	learn: 0.3807197	total: 2.84s	remaining: 2.95s
# 490:	learn: 0.3805958	total: 2.84s	remaining: 2.95s
# 491:	learn: 0.3804869	total: 2.85s	remaining: 2.94s
# 492:	learn: 0.3804217	total: 2.85s	remaining: 2.93s
# 493:	learn: 0.3803027	total: 2.86s	remaining: 2.93s
# 494:	learn: 0.3802289	total: 2.87s	remaining: 2.92s
# 495:	learn: 0.3801313	total: 2.87s	remaining: 2.92s
# 496:	learn: 0.3800546	total: 2.88s	remaining: 2.91s
# 497:	learn: 0.3799487	total: 2.88s	remaining: 2.9s
# 498:	learn: 0.3798478	total: 2.88s	remaining: 2.9s
# 499:	learn: 0.3797605	total: 2.89s	remaining: 2.89s
# 500:	learn: 0.3796951	total: 2.9s	remaining: 2.88s
# 501:	learn: 0.3795724	total: 2.9s	remaining: 2.88s
# 502:	learn: 0.3794848	total: 2.9s	remaining: 2.87s
# 503:	learn: 0.3793787	total: 2.91s	remaining: 2.86s
# 504:	learn: 0.3793094	total: 2.92s	remaining: 2.86s
# 505:	learn: 0.3791939	total: 2.93s	remaining: 2.86s
# 506:	learn: 0.3791383	total: 2.93s	remaining: 2.85s
# 507:	learn: 0.3790468	total: 2.94s	remaining: 2.85s
# 508:	learn: 0.3789743	total: 2.96s	remaining: 2.85s
# 509:	learn: 0.3788704	total: 2.97s	remaining: 2.85s
# 510:	learn: 0.3787905	total: 2.98s	remaining: 2.85s
# 511:	learn: 0.3787097	total: 2.99s	remaining: 2.85s
# 512:	learn: 0.3785827	total: 3s	remaining: 2.85s
# 513:	learn: 0.3784919	total: 3.01s	remaining: 2.85s
# 514:	learn: 0.3784070	total: 3.02s	remaining: 2.85s
# 515:	learn: 0.3783424	total: 3.03s	remaining: 2.85s
# 516:	learn: 0.3782592	total: 3.04s	remaining: 2.84s
# 517:	learn: 0.3781440	total: 3.06s	remaining: 2.84s
# 518:	learn: 0.3780723	total: 3.06s	remaining: 2.84s
# 519:	learn: 0.3780124	total: 3.08s	remaining: 2.84s
# 520:	learn: 0.3779211	total: 3.08s	remaining: 2.84s
# 521:	learn: 0.3778628	total: 3.09s	remaining: 2.83s
# 522:	learn: 0.3778268	total: 3.1s	remaining: 2.83s
# 523:	learn: 0.3777784	total: 3.11s	remaining: 2.83s
# 524:	learn: 0.3776871	total: 3.12s	remaining: 2.83s
# 525:	learn: 0.3776257	total: 3.13s	remaining: 2.82s
# 526:	learn: 0.3775813	total: 3.14s	remaining: 2.82s
# 527:	learn: 0.3775161	total: 3.15s	remaining: 2.82s
# 528:	learn: 0.3774732	total: 3.16s	remaining: 2.82s
# 529:	learn: 0.3773561	total: 3.17s	remaining: 2.81s
# 530:	learn: 0.3772825	total: 3.18s	remaining: 2.81s
# 531:	learn: 0.3772065	total: 3.19s	remaining: 2.81s
# 532:	learn: 0.3771256	total: 3.2s	remaining: 2.81s
# 533:	learn: 0.3770268	total: 3.21s	remaining: 2.8s
# 534:	learn: 0.3769418	total: 3.23s	remaining: 2.81s
# 535:	learn: 0.3768731	total: 3.25s	remaining: 2.81s
# 536:	learn: 0.3767467	total: 3.28s	remaining: 2.83s
# 537:	learn: 0.3766529	total: 3.28s	remaining: 2.82s
# 538:	learn: 0.3765390	total: 3.29s	remaining: 2.81s
# 539:	learn: 0.3764465	total: 3.29s	remaining: 2.8s
# 540:	learn: 0.3763973	total: 3.3s	remaining: 2.8s
# 541:	learn: 0.3763129	total: 3.3s	remaining: 2.79s
# 542:	learn: 0.3762529	total: 3.31s	remaining: 2.78s
# 543:	learn: 0.3761359	total: 3.31s	remaining: 2.78s
# 544:	learn: 0.3761004	total: 3.32s	remaining: 2.77s
# 545:	learn: 0.3760433	total: 3.32s	remaining: 2.76s
# 546:	learn: 0.3759967	total: 3.33s	remaining: 2.75s
# 547:	learn: 0.3759010	total: 3.33s	remaining: 2.75s
# 548:	learn: 0.3758645	total: 3.34s	remaining: 2.74s
# 549:	learn: 0.3757726	total: 3.34s	remaining: 2.73s
# 550:	learn: 0.3756766	total: 3.35s	remaining: 2.73s
# 551:	learn: 0.3755493	total: 3.35s	remaining: 2.72s
# 552:	learn: 0.3754948	total: 3.35s	remaining: 2.71s
# 553:	learn: 0.3754587	total: 3.36s	remaining: 2.71s
# 554:	learn: 0.3753638	total: 3.37s	remaining: 2.7s
# 555:	learn: 0.3752987	total: 3.37s	remaining: 2.69s
# 556:	learn: 0.3752096	total: 3.38s	remaining: 2.68s
# 557:	learn: 0.3751678	total: 3.38s	remaining: 2.68s
# 558:	learn: 0.3750724	total: 3.38s	remaining: 2.67s
# 559:	learn: 0.3750133	total: 3.39s	remaining: 2.66s
# 560:	learn: 0.3749085	total: 3.4s	remaining: 2.66s
# 561:	learn: 0.3748227	total: 3.4s	remaining: 2.65s
# 562:	learn: 0.3747493	total: 3.4s	remaining: 2.64s
# 563:	learn: 0.3746414	total: 3.41s	remaining: 2.63s
# 564:	learn: 0.3745556	total: 3.41s	remaining: 2.63s
# 565:	learn: 0.3744967	total: 3.42s	remaining: 2.62s
# 566:	learn: 0.3743745	total: 3.43s	remaining: 2.62s
# 567:	learn: 0.3742774	total: 3.43s	remaining: 2.61s
# 568:	learn: 0.3742486	total: 3.44s	remaining: 2.6s
# 569:	learn: 0.3741882	total: 3.44s	remaining: 2.59s
# 570:	learn: 0.3741252	total: 3.44s	remaining: 2.59s
# 571:	learn: 0.3739974	total: 3.45s	remaining: 2.58s
# 572:	learn: 0.3739603	total: 3.45s	remaining: 2.57s
# 573:	learn: 0.3738711	total: 3.46s	remaining: 2.57s
# 574:	learn: 0.3737763	total: 3.46s	remaining: 2.56s
# 575:	learn: 0.3737175	total: 3.47s	remaining: 2.55s
# 576:	learn: 0.3736390	total: 3.47s	remaining: 2.55s
# 577:	learn: 0.3735676	total: 3.48s	remaining: 2.54s
# 578:	learn: 0.3734682	total: 3.48s	remaining: 2.53s
# 579:	learn: 0.3733912	total: 3.49s	remaining: 2.53s
# 580:	learn: 0.3733264	total: 3.49s	remaining: 2.52s
# 581:	learn: 0.3732560	total: 3.5s	remaining: 2.51s
# 582:	learn: 0.3731898	total: 3.5s	remaining: 2.51s
# 583:	learn: 0.3731485	total: 3.51s	remaining: 2.5s
# 584:	learn: 0.3730259	total: 3.51s	remaining: 2.49s
# 585:	learn: 0.3729415	total: 3.52s	remaining: 2.48s
# 586:	learn: 0.3728571	total: 3.52s	remaining: 2.48s
# 587:	learn: 0.3727680	total: 3.53s	remaining: 2.47s
# 588:	learn: 0.3727107	total: 3.53s	remaining: 2.46s
# 589:	learn: 0.3726513	total: 3.54s	remaining: 2.46s
# 590:	learn: 0.3725741	total: 3.54s	remaining: 2.45s
# 591:	learn: 0.3724752	total: 3.55s	remaining: 2.44s
# 592:	learn: 0.3723728	total: 3.55s	remaining: 2.44s
# 593:	learn: 0.3722744	total: 3.56s	remaining: 2.43s
# 594:	learn: 0.3722083	total: 3.56s	remaining: 2.43s
# 595:	learn: 0.3721603	total: 3.57s	remaining: 2.42s
# 596:	learn: 0.3720750	total: 3.58s	remaining: 2.41s
# 597:	learn: 0.3720141	total: 3.58s	remaining: 2.41s
# 598:	learn: 0.3719285	total: 3.59s	remaining: 2.4s
# 599:	learn: 0.3718684	total: 3.59s	remaining: 2.39s
# 600:	learn: 0.3718172	total: 3.6s	remaining: 2.39s
# 601:	learn: 0.3717441	total: 3.6s	remaining: 2.38s
# 602:	learn: 0.3716298	total: 3.6s	remaining: 2.37s
# 603:	learn: 0.3715508	total: 3.61s	remaining: 2.37s
# 604:	learn: 0.3714844	total: 3.61s	remaining: 2.36s
# 605:	learn: 0.3714259	total: 3.62s	remaining: 2.35s
# 606:	learn: 0.3713295	total: 3.63s	remaining: 2.35s
# 607:	learn: 0.3712634	total: 3.63s	remaining: 2.34s
# 608:	learn: 0.3711826	total: 3.63s	remaining: 2.33s
# 609:	learn: 0.3711097	total: 3.64s	remaining: 2.33s
# 610:	learn: 0.3710393	total: 3.64s	remaining: 2.32s
# 611:	learn: 0.3709750	total: 3.65s	remaining: 2.31s
# 612:	learn: 0.3709462	total: 3.65s	remaining: 2.31s
# 613:	learn: 0.3709182	total: 3.66s	remaining: 2.3s
# 614:	learn: 0.3708533	total: 3.66s	remaining: 2.29s
# 615:	learn: 0.3707840	total: 3.67s	remaining: 2.29s
# 616:	learn: 0.3706995	total: 3.67s	remaining: 2.28s
# 617:	learn: 0.3705769	total: 3.68s	remaining: 2.27s
# 618:	learn: 0.3705084	total: 3.68s	remaining: 2.27s
# 619:	learn: 0.3704513	total: 3.69s	remaining: 2.26s
# 620:	learn: 0.3703587	total: 3.69s	remaining: 2.25s
# 621:	learn: 0.3702975	total: 3.7s	remaining: 2.25s
# 622:	learn: 0.3702063	total: 3.7s	remaining: 2.24s
# 623:	learn: 0.3701452	total: 3.71s	remaining: 2.23s
# 624:	learn: 0.3700105	total: 3.71s	remaining: 2.23s
# 625:	learn: 0.3699456	total: 3.72s	remaining: 2.22s
# 626:	learn: 0.3698416	total: 3.72s	remaining: 2.21s
# 627:	learn: 0.3697029	total: 3.73s	remaining: 2.21s
# 628:	learn: 0.3696053	total: 3.73s	remaining: 2.2s
# 629:	learn: 0.3695100	total: 3.74s	remaining: 2.2s
# 630:	learn: 0.3694338	total: 3.75s	remaining: 2.19s
# 631:	learn: 0.3693673	total: 3.75s	remaining: 2.18s
# 632:	learn: 0.3692940	total: 3.75s	remaining: 2.18s
# 633:	learn: 0.3691993	total: 3.76s	remaining: 2.17s
# 634:	learn: 0.3691412	total: 3.77s	remaining: 2.16s
# 635:	learn: 0.3690856	total: 3.77s	remaining: 2.16s
# 636:	learn: 0.3689857	total: 3.78s	remaining: 2.15s
# 637:	learn: 0.3689124	total: 3.78s	remaining: 2.15s
# 638:	learn: 0.3688469	total: 3.79s	remaining: 2.14s
# 639:	learn: 0.3687520	total: 3.79s	remaining: 2.13s
# 640:	learn: 0.3686718	total: 3.8s	remaining: 2.13s
# 641:	learn: 0.3685827	total: 3.8s	remaining: 2.12s
# 642:	learn: 0.3684975	total: 3.81s	remaining: 2.12s
# 643:	learn: 0.3684615	total: 3.81s	remaining: 2.11s
# 644:	learn: 0.3683554	total: 3.82s	remaining: 2.1s
# 645:	learn: 0.3682744	total: 3.83s	remaining: 2.1s
# 646:	learn: 0.3681749	total: 3.83s	remaining: 2.09s
# 647:	learn: 0.3680718	total: 3.84s	remaining: 2.09s
# 648:	learn: 0.3680000	total: 3.85s	remaining: 2.08s
# 649:	learn: 0.3679208	total: 3.86s	remaining: 2.08s
# 650:	learn: 0.3678784	total: 3.87s	remaining: 2.07s
# 651:	learn: 0.3678010	total: 3.88s	remaining: 2.07s
# 652:	learn: 0.3677179	total: 3.89s	remaining: 2.06s
# 653:	learn: 0.3676151	total: 3.9s	remaining: 2.07s
# 654:	learn: 0.3675330	total: 3.91s	remaining: 2.06s
# 655:	learn: 0.3674638	total: 3.92s	remaining: 2.06s
# 656:	learn: 0.3673708	total: 3.93s	remaining: 2.05s
# 657:	learn: 0.3673090	total: 3.94s	remaining: 2.05s
# 658:	learn: 0.3672449	total: 3.95s	remaining: 2.04s
# 659:	learn: 0.3671662	total: 3.96s	remaining: 2.04s
# 660:	learn: 0.3670725	total: 3.97s	remaining: 2.03s
# 661:	learn: 0.3669493	total: 3.97s	remaining: 2.03s
# 662:	learn: 0.3668805	total: 3.98s	remaining: 2.02s
# 663:	learn: 0.3668256	total: 3.98s	remaining: 2.02s
# 664:	learn: 0.3667630	total: 3.99s	remaining: 2.01s
# 665:	learn: 0.3666772	total: 3.99s	remaining: 2s
# 666:	learn: 0.3666108	total: 4s	remaining: 2s
# 667:	learn: 0.3665431	total: 4s	remaining: 1.99s
# 668:	learn: 0.3664532	total: 4.01s	remaining: 1.98s
# 669:	learn: 0.3663685	total: 4.01s	remaining: 1.98s
# 670:	learn: 0.3662722	total: 4.02s	remaining: 1.97s
# 671:	learn: 0.3662100	total: 4.03s	remaining: 1.96s
# 672:	learn: 0.3661269	total: 4.03s	remaining: 1.96s
# 673:	learn: 0.3660529	total: 4.04s	remaining: 1.95s
# 674:	learn: 0.3659926	total: 4.04s	remaining: 1.95s
# 675:	learn: 0.3659213	total: 4.05s	remaining: 1.94s
# 676:	learn: 0.3658321	total: 4.05s	remaining: 1.93s
# 677:	learn: 0.3657546	total: 4.06s	remaining: 1.93s
# 678:	learn: 0.3656824	total: 4.07s	remaining: 1.92s
# 679:	learn: 0.3656138	total: 4.08s	remaining: 1.92s
# 680:	learn: 0.3655263	total: 4.08s	remaining: 1.91s
# 681:	learn: 0.3654771	total: 4.08s	remaining: 1.9s
# 682:	learn: 0.3654220	total: 4.09s	remaining: 1.9s
# 683:	learn: 0.3653214	total: 4.1s	remaining: 1.89s
# 684:	learn: 0.3652481	total: 4.1s	remaining: 1.89s
# 685:	learn: 0.3651872	total: 4.11s	remaining: 1.88s
# 686:	learn: 0.3650766	total: 4.11s	remaining: 1.87s
# 687:	learn: 0.3650317	total: 4.12s	remaining: 1.87s
# 688:	learn: 0.3649621	total: 4.12s	remaining: 1.86s
# 689:	learn: 0.3649106	total: 4.13s	remaining: 1.85s
# 690:	learn: 0.3648442	total: 4.13s	remaining: 1.85s
# 691:	learn: 0.3647679	total: 4.14s	remaining: 1.84s
# 692:	learn: 0.3647072	total: 4.14s	remaining: 1.83s
# 693:	learn: 0.3646090	total: 4.15s	remaining: 1.83s
# 694:	learn: 0.3645530	total: 4.16s	remaining: 1.82s
# 695:	learn: 0.3644954	total: 4.16s	remaining: 1.82s
# 696:	learn: 0.3644446	total: 4.17s	remaining: 1.81s
# 697:	learn: 0.3644015	total: 4.17s	remaining: 1.8s
# 698:	learn: 0.3643271	total: 4.18s	remaining: 1.8s
# 699:	learn: 0.3642781	total: 4.18s	remaining: 1.79s
# 700:	learn: 0.3642304	total: 4.19s	remaining: 1.78s
# 701:	learn: 0.3641385	total: 4.19s	remaining: 1.78s
# 702:	learn: 0.3640612	total: 4.2s	remaining: 1.77s
# 703:	learn: 0.3640183	total: 4.2s	remaining: 1.77s
# 704:	learn: 0.3639483	total: 4.21s	remaining: 1.76s
# 705:	learn: 0.3639224	total: 4.21s	remaining: 1.75s
# 706:	learn: 0.3638535	total: 4.22s	remaining: 1.75s
# 707:	learn: 0.3637882	total: 4.22s	remaining: 1.74s
# 708:	learn: 0.3637134	total: 4.23s	remaining: 1.74s
# 709:	learn: 0.3636166	total: 4.23s	remaining: 1.73s
# 710:	learn: 0.3635640	total: 4.24s	remaining: 1.72s
# 711:	learn: 0.3634719	total: 4.24s	remaining: 1.72s
# 712:	learn: 0.3634251	total: 4.25s	remaining: 1.71s
# 713:	learn: 0.3633532	total: 4.25s	remaining: 1.7s
# 714:	learn: 0.3632998	total: 4.26s	remaining: 1.7s
# 715:	learn: 0.3631997	total: 4.26s	remaining: 1.69s
# 716:	learn: 0.3631192	total: 4.27s	remaining: 1.68s
# 717:	learn: 0.3630127	total: 4.27s	remaining: 1.68s
# 718:	learn: 0.3629234	total: 4.28s	remaining: 1.67s
# 719:	learn: 0.3628450	total: 4.28s	remaining: 1.67s
# 720:	learn: 0.3627465	total: 4.29s	remaining: 1.66s
# 721:	learn: 0.3626889	total: 4.29s	remaining: 1.65s
# 722:	learn: 0.3626059	total: 4.3s	remaining: 1.65s
# 723:	learn: 0.3625412	total: 4.3s	remaining: 1.64s
# 724:	learn: 0.3624699	total: 4.31s	remaining: 1.63s
# 725:	learn: 0.3623676	total: 4.31s	remaining: 1.63s
# 726:	learn: 0.3622710	total: 4.32s	remaining: 1.62s
# 727:	learn: 0.3622262	total: 4.32s	remaining: 1.61s
# 728:	learn: 0.3621241	total: 4.33s	remaining: 1.61s
# 729:	learn: 0.3620237	total: 4.33s	remaining: 1.6s
# 730:	learn: 0.3619767	total: 4.34s	remaining: 1.6s
# 731:	learn: 0.3619247	total: 4.34s	remaining: 1.59s
# 732:	learn: 0.3618749	total: 4.35s	remaining: 1.58s
# 733:	learn: 0.3617503	total: 4.35s	remaining: 1.58s
# 734:	learn: 0.3617161	total: 4.36s	remaining: 1.57s
# 735:	learn: 0.3616541	total: 4.36s	remaining: 1.56s
# 736:	learn: 0.3615430	total: 4.37s	remaining: 1.56s
# 737:	learn: 0.3615009	total: 4.37s	remaining: 1.55s
# 738:	learn: 0.3614052	total: 4.38s	remaining: 1.54s
# 739:	learn: 0.3613431	total: 4.38s	remaining: 1.54s
# 740:	learn: 0.3612756	total: 4.39s	remaining: 1.53s
# 741:	learn: 0.3612219	total: 4.39s	remaining: 1.53s
# 742:	learn: 0.3611338	total: 4.4s	remaining: 1.52s
# 743:	learn: 0.3610749	total: 4.4s	remaining: 1.51s
# 744:	learn: 0.3609854	total: 4.41s	remaining: 1.51s
# 745:	learn: 0.3608969	total: 4.41s	remaining: 1.5s
# 746:	learn: 0.3608246	total: 4.42s	remaining: 1.5s
# 747:	learn: 0.3607617	total: 4.42s	remaining: 1.49s
# 748:	learn: 0.3606586	total: 4.43s	remaining: 1.48s
# 749:	learn: 0.3606009	total: 4.43s	remaining: 1.48s
# 750:	learn: 0.3605793	total: 4.44s	remaining: 1.47s
# 751:	learn: 0.3605250	total: 4.44s	remaining: 1.46s
# 752:	learn: 0.3604534	total: 4.45s	remaining: 1.46s
# 753:	learn: 0.3603986	total: 4.45s	remaining: 1.45s
# 754:	learn: 0.3603382	total: 4.46s	remaining: 1.45s
# 755:	learn: 0.3602716	total: 4.46s	remaining: 1.44s
# 756:	learn: 0.3601973	total: 4.47s	remaining: 1.43s
# 757:	learn: 0.3601190	total: 4.47s	remaining: 1.43s
# 758:	learn: 0.3600428	total: 4.48s	remaining: 1.42s
# 759:	learn: 0.3600017	total: 4.48s	remaining: 1.42s
# 760:	learn: 0.3599309	total: 4.49s	remaining: 1.41s
# 761:	learn: 0.3598964	total: 4.49s	remaining: 1.4s
# 762:	learn: 0.3598744	total: 4.5s	remaining: 1.4s
# 763:	learn: 0.3597984	total: 4.5s	remaining: 1.39s
# 764:	learn: 0.3597380	total: 4.51s	remaining: 1.38s
# 765:	learn: 0.3596757	total: 4.51s	remaining: 1.38s
# 766:	learn: 0.3596434	total: 4.52s	remaining: 1.37s
# 767:	learn: 0.3595300	total: 4.52s	remaining: 1.37s
# 768:	learn: 0.3594575	total: 4.53s	remaining: 1.36s
# 769:	learn: 0.3594099	total: 4.54s	remaining: 1.35s
# 770:	learn: 0.3593372	total: 4.54s	remaining: 1.35s
# 771:	learn: 0.3592472	total: 4.56s	remaining: 1.34s
# 772:	learn: 0.3591258	total: 4.57s	remaining: 1.34s
# 773:	learn: 0.3590515	total: 4.58s	remaining: 1.34s
# 774:	learn: 0.3589925	total: 4.59s	remaining: 1.33s
# 775:	learn: 0.3589268	total: 4.6s	remaining: 1.33s
# 776:	learn: 0.3588702	total: 4.6s	remaining: 1.32s
# 777:	learn: 0.3588239	total: 4.61s	remaining: 1.31s
# 778:	learn: 0.3587922	total: 4.62s	remaining: 1.31s
# 779:	learn: 0.3587289	total: 4.63s	remaining: 1.3s
# 780:	learn: 0.3587020	total: 4.63s	remaining: 1.3s
# 781:	learn: 0.3586261	total: 4.64s	remaining: 1.29s
# 782:	learn: 0.3585468	total: 4.65s	remaining: 1.29s
# 783:	learn: 0.3584660	total: 4.66s	remaining: 1.28s
# 784:	learn: 0.3583813	total: 4.66s	remaining: 1.28s
# 785:	learn: 0.3583270	total: 4.67s	remaining: 1.27s
# 786:	learn: 0.3582510	total: 4.68s	remaining: 1.26s
# 787:	learn: 0.3581750	total: 4.68s	remaining: 1.26s
# 788:	learn: 0.3581349	total: 4.69s	remaining: 1.25s
# 789:	learn: 0.3581033	total: 4.7s	remaining: 1.25s
# 790:	learn: 0.3580244	total: 4.7s	remaining: 1.24s
# 791:	learn: 0.3579934	total: 4.71s	remaining: 1.24s
# 792:	learn: 0.3579796	total: 4.71s	remaining: 1.23s
# 793:	learn: 0.3579418	total: 4.72s	remaining: 1.22s
# 794:	learn: 0.3578952	total: 4.73s	remaining: 1.22s
# 795:	learn: 0.3578512	total: 4.73s	remaining: 1.21s
# 796:	learn: 0.3577966	total: 4.74s	remaining: 1.21s
# 797:	learn: 0.3577499	total: 4.75s	remaining: 1.2s
# 798:	learn: 0.3576803	total: 4.75s	remaining: 1.2s
# 799:	learn: 0.3575915	total: 4.76s	remaining: 1.19s
# 800:	learn: 0.3575841	total: 4.77s	remaining: 1.18s
# 801:	learn: 0.3574757	total: 4.77s	remaining: 1.18s
# 802:	learn: 0.3573656	total: 4.78s	remaining: 1.17s
# 803:	learn: 0.3572884	total: 4.79s	remaining: 1.17s
# 804:	learn: 0.3571493	total: 4.79s	remaining: 1.16s
# 805:	learn: 0.3570729	total: 4.8s	remaining: 1.16s
# 806:	learn: 0.3569970	total: 4.81s	remaining: 1.15s
# 807:	learn: 0.3569351	total: 4.81s	remaining: 1.14s
# 808:	learn: 0.3568600	total: 4.82s	remaining: 1.14s
# 809:	learn: 0.3568156	total: 4.83s	remaining: 1.13s
# 810:	learn: 0.3567710	total: 4.83s	remaining: 1.13s
# 811:	learn: 0.3567000	total: 4.84s	remaining: 1.12s
# 812:	learn: 0.3566020	total: 4.84s	remaining: 1.11s
# 813:	learn: 0.3565389	total: 4.85s	remaining: 1.11s
# 814:	learn: 0.3564922	total: 4.86s	remaining: 1.1s
# 815:	learn: 0.3564053	total: 4.86s	remaining: 1.1s
# 816:	learn: 0.3562693	total: 4.87s	remaining: 1.09s
# 817:	learn: 0.3562021	total: 4.87s	remaining: 1.08s
# 818:	learn: 0.3561337	total: 4.88s	remaining: 1.08s
# 819:	learn: 0.3560446	total: 4.88s	remaining: 1.07s
# 820:	learn: 0.3559666	total: 4.89s	remaining: 1.07s
# 821:	learn: 0.3558993	total: 4.9s	remaining: 1.06s
# 822:	learn: 0.3558195	total: 4.9s	remaining: 1.05s
# 823:	learn: 0.3557649	total: 4.91s	remaining: 1.05s
# 824:	learn: 0.3556885	total: 4.92s	remaining: 1.04s
# 825:	learn: 0.3556058	total: 4.92s	remaining: 1.04s
# 826:	learn: 0.3555473	total: 4.93s	remaining: 1.03s
# 827:	learn: 0.3554788	total: 4.93s	remaining: 1.02s
# 828:	learn: 0.3553934	total: 4.94s	remaining: 1.02s
# 829:	learn: 0.3553220	total: 4.94s	remaining: 1.01s
# 830:	learn: 0.3552415	total: 4.95s	remaining: 1.01s
# 831:	learn: 0.3551865	total: 4.95s	remaining: 1s
# 832:	learn: 0.3551013	total: 4.96s	remaining: 994ms
# 833:	learn: 0.3550243	total: 4.97s	remaining: 989ms
# 834:	learn: 0.3549540	total: 4.97s	remaining: 983ms
# 835:	learn: 0.3548548	total: 4.98s	remaining: 977ms
# 836:	learn: 0.3547642	total: 4.99s	remaining: 971ms
# 837:	learn: 0.3547057	total: 4.99s	remaining: 965ms
# 838:	learn: 0.3546430	total: 5s	remaining: 959ms
# 839:	learn: 0.3545441	total: 5.01s	remaining: 955ms
# 840:	learn: 0.3544703	total: 5.02s	remaining: 950ms
# 841:	learn: 0.3544348	total: 5.03s	remaining: 944ms
# 842:	learn: 0.3543505	total: 5.04s	remaining: 939ms
# 843:	learn: 0.3543061	total: 5.05s	remaining: 934ms
# 844:	learn: 0.3541983	total: 5.06s	remaining: 928ms
# 845:	learn: 0.3541176	total: 5.07s	remaining: 924ms
# 846:	learn: 0.3540526	total: 5.09s	remaining: 920ms
# 847:	learn: 0.3539828	total: 5.11s	remaining: 917ms
# 848:	learn: 0.3539390	total: 5.13s	remaining: 912ms
# 849:	learn: 0.3538753	total: 5.14s	remaining: 907ms
# 850:	learn: 0.3537718	total: 5.14s	remaining: 901ms
# 851:	learn: 0.3536778	total: 5.15s	remaining: 895ms
# 852:	learn: 0.3536001	total: 5.16s	remaining: 889ms
# 853:	learn: 0.3535144	total: 5.16s	remaining: 883ms
# 854:	learn: 0.3534498	total: 5.17s	remaining: 877ms
# 855:	learn: 0.3533744	total: 5.17s	remaining: 871ms
# 856:	learn: 0.3532563	total: 5.18s	remaining: 865ms
# 857:	learn: 0.3531703	total: 5.19s	remaining: 859ms
# 858:	learn: 0.3530925	total: 5.19s	remaining: 853ms
# 859:	learn: 0.3530426	total: 5.2s	remaining: 847ms
# 860:	learn: 0.3529955	total: 5.21s	remaining: 841ms
# 861:	learn: 0.3529587	total: 5.21s	remaining: 835ms
# 862:	learn: 0.3528723	total: 5.22s	remaining: 829ms
# 863:	learn: 0.3528022	total: 5.22s	remaining: 822ms
# 864:	learn: 0.3527522	total: 5.23s	remaining: 817ms
# 865:	learn: 0.3526932	total: 5.24s	remaining: 810ms
# 866:	learn: 0.3525831	total: 5.24s	remaining: 804ms
# 867:	learn: 0.3525206	total: 5.25s	remaining: 798ms
# 868:	learn: 0.3524297	total: 5.25s	remaining: 792ms
# 869:	learn: 0.3524010	total: 5.26s	remaining: 787ms
# 870:	learn: 0.3523443	total: 5.27s	remaining: 781ms
# 871:	learn: 0.3522645	total: 5.28s	remaining: 774ms
# 872:	learn: 0.3521874	total: 5.28s	remaining: 769ms
# 873:	learn: 0.3520872	total: 5.29s	remaining: 763ms
# 874:	learn: 0.3520182	total: 5.3s	remaining: 757ms
# 875:	learn: 0.3520157	total: 5.3s	remaining: 751ms
# 876:	learn: 0.3519512	total: 5.31s	remaining: 745ms
# 877:	learn: 0.3519046	total: 5.32s	remaining: 739ms
# 878:	learn: 0.3518400	total: 5.32s	remaining: 733ms
# 879:	learn: 0.3517801	total: 5.33s	remaining: 727ms
# 880:	learn: 0.3517349	total: 5.34s	remaining: 721ms
# 881:	learn: 0.3516524	total: 5.34s	remaining: 715ms
# 882:	learn: 0.3515928	total: 5.35s	remaining: 709ms
# 883:	learn: 0.3514868	total: 5.36s	remaining: 703ms
# 884:	learn: 0.3514191	total: 5.36s	remaining: 697ms
# 885:	learn: 0.3513774	total: 5.37s	remaining: 691ms
# 886:	learn: 0.3513226	total: 5.37s	remaining: 685ms
# 887:	learn: 0.3512709	total: 5.38s	remaining: 679ms
# 888:	learn: 0.3512259	total: 5.39s	remaining: 673ms
# 889:	learn: 0.3511874	total: 5.39s	remaining: 667ms
# 890:	learn: 0.3511053	total: 5.4s	remaining: 661ms
# 891:	learn: 0.3510743	total: 5.41s	remaining: 654ms
# 892:	learn: 0.3509870	total: 5.41s	remaining: 649ms
# 893:	learn: 0.3509360	total: 5.42s	remaining: 643ms
# 894:	learn: 0.3508880	total: 5.43s	remaining: 637ms
# 895:	learn: 0.3508000	total: 5.43s	remaining: 631ms
# 896:	learn: 0.3507042	total: 5.44s	remaining: 624ms
# 897:	learn: 0.3506111	total: 5.44s	remaining: 618ms
# 898:	learn: 0.3505556	total: 5.45s	remaining: 612ms
# 899:	learn: 0.3504510	total: 5.45s	remaining: 606ms
# 900:	learn: 0.3503868	total: 5.46s	remaining: 600ms
# 901:	learn: 0.3503528	total: 5.47s	remaining: 594ms
# 902:	learn: 0.3502852	total: 5.47s	remaining: 588ms
# 903:	learn: 0.3502339	total: 5.48s	remaining: 582ms
# 904:	learn: 0.3501670	total: 5.49s	remaining: 576ms
# 905:	learn: 0.3501359	total: 5.49s	remaining: 570ms
# 906:	learn: 0.3500972	total: 5.5s	remaining: 564ms
# 907:	learn: 0.3500361	total: 5.51s	remaining: 558ms
# 908:	learn: 0.3499729	total: 5.53s	remaining: 553ms
# 909:	learn: 0.3499149	total: 5.54s	remaining: 547ms
# 910:	learn: 0.3498252	total: 5.54s	remaining: 542ms
# 911:	learn: 0.3497727	total: 5.55s	remaining: 536ms
# 912:	learn: 0.3497132	total: 5.56s	remaining: 530ms
# 913:	learn: 0.3496519	total: 5.57s	remaining: 524ms
# 914:	learn: 0.3495849	total: 5.58s	remaining: 518ms
# 915:	learn: 0.3495323	total: 5.58s	remaining: 512ms
# 916:	learn: 0.3493965	total: 5.59s	remaining: 506ms
# 917:	learn: 0.3493227	total: 5.6s	remaining: 500ms
# 918:	learn: 0.3492675	total: 5.61s	remaining: 494ms
# 919:	learn: 0.3491752	total: 5.61s	remaining: 488ms
# 920:	learn: 0.3491184	total: 5.62s	remaining: 482ms
# 921:	learn: 0.3490194	total: 5.62s	remaining: 476ms
# 922:	learn: 0.3489427	total: 5.63s	remaining: 470ms
# 923:	learn: 0.3488541	total: 5.63s	remaining: 464ms
# 924:	learn: 0.3487966	total: 5.64s	remaining: 457ms
# 925:	learn: 0.3486982	total: 5.65s	remaining: 451ms
# 926:	learn: 0.3485949	total: 5.65s	remaining: 445ms
# 927:	learn: 0.3485206	total: 5.66s	remaining: 439ms
# 928:	learn: 0.3484633	total: 5.67s	remaining: 433ms
# 929:	learn: 0.3483974	total: 5.67s	remaining: 427ms
# 930:	learn: 0.3483167	total: 5.68s	remaining: 421ms
# 931:	learn: 0.3482481	total: 5.68s	remaining: 415ms
# 932:	learn: 0.3482022	total: 5.69s	remaining: 408ms
# 933:	learn: 0.3481134	total: 5.7s	remaining: 402ms
# 934:	learn: 0.3480527	total: 5.7s	remaining: 396ms
# 935:	learn: 0.3480158	total: 5.71s	remaining: 390ms
# 936:	learn: 0.3479523	total: 5.71s	remaining: 384ms
# 937:	learn: 0.3479069	total: 5.72s	remaining: 378ms
# 938:	learn: 0.3478320	total: 5.72s	remaining: 372ms
# 939:	learn: 0.3477472	total: 5.73s	remaining: 366ms
# 940:	learn: 0.3476734	total: 5.74s	remaining: 360ms
# 941:	learn: 0.3476266	total: 5.74s	remaining: 354ms
# 942:	learn: 0.3475272	total: 5.75s	remaining: 347ms
# 943:	learn: 0.3474303	total: 5.75s	remaining: 341ms
# 944:	learn: 0.3473665	total: 5.76s	remaining: 335ms
# 945:	learn: 0.3472987	total: 5.76s	remaining: 329ms
# 946:	learn: 0.3471707	total: 5.77s	remaining: 323ms
# 947:	learn: 0.3471421	total: 5.78s	remaining: 317ms
# 948:	learn: 0.3471005	total: 5.78s	remaining: 311ms
# 949:	learn: 0.3470694	total: 5.79s	remaining: 305ms
# 950:	learn: 0.3470181	total: 5.79s	remaining: 299ms
# 951:	learn: 0.3469509	total: 5.8s	remaining: 292ms
# 952:	learn: 0.3469122	total: 5.8s	remaining: 286ms
# 953:	learn: 0.3468291	total: 5.81s	remaining: 280ms
# 954:	learn: 0.3467677	total: 5.82s	remaining: 274ms
# 955:	learn: 0.3467066	total: 5.82s	remaining: 268ms
# 956:	learn: 0.3466043	total: 5.83s	remaining: 262ms
# 957:	learn: 0.3465233	total: 5.83s	remaining: 256ms
# 958:	learn: 0.3464360	total: 5.84s	remaining: 250ms
# 959:	learn: 0.3463346	total: 5.84s	remaining: 244ms
# 960:	learn: 0.3462512	total: 5.85s	remaining: 237ms
# 961:	learn: 0.3461926	total: 5.86s	remaining: 231ms
# 962:	learn: 0.3460992	total: 5.86s	remaining: 225ms
# 963:	learn: 0.3460738	total: 5.87s	remaining: 219ms
# 964:	learn: 0.3459819	total: 5.88s	remaining: 213ms
# 965:	learn: 0.3458966	total: 5.88s	remaining: 207ms
# 966:	learn: 0.3458358	total: 5.88s	remaining: 201ms
# 967:	learn: 0.3458062	total: 5.89s	remaining: 195ms
# 968:	learn: 0.3457375	total: 5.9s	remaining: 189ms
# 969:	learn: 0.3456519	total: 5.9s	remaining: 183ms
# 970:	learn: 0.3455643	total: 5.91s	remaining: 177ms
# 971:	learn: 0.3454866	total: 5.91s	remaining: 170ms
# 972:	learn: 0.3453919	total: 5.92s	remaining: 164ms
# 973:	learn: 0.3453181	total: 5.93s	remaining: 158ms
# 974:	learn: 0.3452528	total: 5.93s	remaining: 152ms
# 975:	learn: 0.3451771	total: 5.94s	remaining: 146ms
# 976:	learn: 0.3450692	total: 5.94s	remaining: 140ms
# 977:	learn: 0.3450069	total: 5.95s	remaining: 134ms
# 978:	learn: 0.3449350	total: 5.96s	remaining: 128ms
# 979:	learn: 0.3448893	total: 5.96s	remaining: 122ms
# 980:	learn: 0.3448099	total: 5.97s	remaining: 116ms
# 981:	learn: 0.3447507	total: 5.97s	remaining: 109ms
# 982:	learn: 0.3446679	total: 5.98s	remaining: 103ms
# 983:	learn: 0.3446178	total: 5.98s	remaining: 97.3ms
# 984:	learn: 0.3445515	total: 5.99s	remaining: 91.2ms
# 985:	learn: 0.3444635	total: 5.99s	remaining: 85.1ms
# 986:	learn: 0.3444032	total: 6s	remaining: 79ms
# 987:	learn: 0.3443674	total: 6s	remaining: 72.9ms
# 988:	learn: 0.3443314	total: 6.01s	remaining: 66.9ms
# 989:	learn: 0.3442681	total: 6.02s	remaining: 60.8ms
# 990:	learn: 0.3441725	total: 6.03s	remaining: 54.7ms
# 991:	learn: 0.3440625	total: 6.03s	remaining: 48.6ms
# 992:	learn: 0.3439746	total: 6.04s	remaining: 42.5ms
# 993:	learn: 0.3439334	total: 6.04s	remaining: 36.5ms
# 994:	learn: 0.3438702	total: 6.04s	remaining: 30.4ms
# 995:	learn: 0.3438333	total: 6.05s	remaining: 24.3ms
# 996:	learn: 0.3437559	total: 6.06s	remaining: 18.2ms
# 997:	learn: 0.3436890	total: 6.06s	remaining: 12.2ms
# 998:	learn: 0.3436512	total: 6.07s	remaining: 6.08ms
# 999:	learn: 0.3435862	total: 6.08s	remaining: 0us
# The f1_score of CatBoost is 0.8415714781050456

# %%
# importances = cat.feature_importances_
# indices = np.argsort(importances)[::-1]
# names = [train_X.columns[i] for i in indices]
# plt.figure(figsize=(30,15))
# plt.title("Feature Importance")
# plt.bar(range(train_X.shape[1]), importances[indices])
# plt.xticks(range(train_X.shape[1]), names, rotation=90)
# plt.show()

# %% [markdown]
# ### kNN

# %%
from sklearn.neighbors import KNeighborsClassifier
training_f1 = []
test_f1 = []
# try n_neighbors from 1 to 10
neighbors_settings = range(1, 11)
for n_neighbors in neighbors_settings:
    # build the model
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)
    knn.fit(train_X, train_y)
    # record training set accuracy
    training_f1.append(f1_score(knn.predict(train_X),train_y,average='weighted'))
    # record test set accuracy
    test_f1.append(f1_score(knn.predict(test_X),test_y,average='weighted'))
plt.plot(neighbors_settings, training_f1, label="training accuracy")
plt.plot(neighbors_settings, test_f1, label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()
plt.savefig('knn_compare_model')

# %%
print("Highest f1 :"+str(max(test_f1)))
# Out:
# Highest f1 :0.8365916691387768

# %% [markdown]
# ### Summary:
#
# In this project. I compared different machine learning models: **Decision Tree, Random Forests, Linear Regression, Logistic Regression, XGBClassifier, CatBoost Classifier and kNN**. Results and accuracies are listed above.
#
# In conclusion, **CatBoost Classifier** has the highest accuracy (82%), it's the best model to do prediction for this dataset. However, **Linear Regression**'s accucary is only 11%, so we should not use it in prediction.

# %% [markdown]
# ## Catboost

# %% [markdown]
# Catboost was released in 2017 by Yandex, showing, by their benchmark to be faster in prediction, better in accuracy, and easier to use for categorical data across a series of GBDT tasks.
#
# Catboost introduces ordered boosting as a better gradient boosting algorithm but the greatest innovation of catboost is how it deals with categorical data. Categorical data introduces several challenges because it has to have a numerical encoding. We could use dummy variables that split the column of n categories into n columns of one-hot encoded features but this can explode our feature set. One tactic is to use target mean encoding, where we assign our category value to the mean of the target variable for that category. Catboost uses a variation on target encoding that calculates the target encoding with available history and a random permutation to encode and process our categorical data. Catboost uses the available history instead of the mean because a model running in real time would not know the true mean for its target. In training we can, of course, calculate the mean because we have all the data and this leads to target leakage where the training accuracy for our model is inflated in comparison to its accuracy in production.
#
# Additional capabilities of catboost include plotting feature interactions and object (row) importance.

# %% [markdown]
# ### Important Hyperparameters
#
# learning_rate (defualt=0.03): Dictates reduction in gradient step.<br>
#
# iterations (default=1000): Max number of trees that can be built when solving machine learning problems.<br>
#
# l2_leaf_reg (defualt=3): L2 regularization coefficient for leaf calculation, any positive values are allowed.<br>
#
# depth (default=6): Depth of trees, like in XGB it has a high impact on accuracy and training time. It can be any integer up to 32 but a good range is 1-10.<br>
#
# random_strength: The amount of randomness to use for scoring splits, used to avoid overfitting.<br>
#
# bagging_temperature: Defines the settings of the Bayesian bootstrap, bootstrap_type defines the sampling of the weights, Bayesian is the defualt. If set to 1 weights are sampled from an exponential distribution, if 0 then all weights are equal to 1.<br>
#
# border_count(default=254 for cpu, 128 for gpu): The number of splits for numerical features, integers between 1 and 255 are allowed.
#
# ctr_border_count: The number of splits for categorical features. All values are integers from 1 to 255.
